# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import math

from collections import Counter
# =============================================================================
# 1. CÀI ĐẶT BÀI TOÁN VÀ DỮ LIỆU 
# =============================================================================

# Các tham số chính của bài toán
NUM_BASIC_AREAS = 50  # |B| - Số khu vực cơ bản
MAP_SIZE = 26  # Kích thước bản đồ (100m)

# =============================================================================
# DEPOT - KHO HÀNG
# =============================================================================
DEPOT = {'x': 13, 'y': 13}  # Tọa độ kho hàng ở trung tâm

# =============================================================================
# THÔNG SỐ VẬN HÀNH (Operational Parameters)
# =============================================================================
TRAVEL_SPEED = 500  #- Tốc độ di chuyển trung bình
RELOAD_TIME = 0.25  #  t_reload: Thời gian nạp lại hàng tại depot
T_MAX = 8.0  #  Thời gian làm việc tối đa của tài xế full-time

# =============================================================================
# DRIVER TYPES - D = {1, ..., |D|}
# =============================================================================
DRIVER_TYPES = [
    {
        'id': 1,
        'name': 'Full-time',
        'r_d': 1.0,      # Phần trăm thời gian làm việc (100% = full-time)
        'M_d': 2,        # Số lượng tài xế loại này
        'work_time': T_MAX * 1.0  # 8.0 giờ
    },
    {
        'id': 2,
        'name': 'Part-time (75%)',
        'r_d': 0.75,     # 75% thời gian full-time
        'M_d': 0,        # Số lượng tài xế loại này
        'work_time': T_MAX * 0.75  # 6.0 giờ
    },
    {
        'id': 3,
        'name': 'Part-time (62.5%)',
        'r_d': 0.625,    # 62.5% thời gian full-time
        'M_d': 0,        # Số lượng tài xế loại này
        'work_time': T_MAX * 0.625  # 5.0 giờ
    },
    {
        'id': 4,
        'name': 'Part-time (56.25%)',
        'r_d': 0.5625,   # 56.25% thời gian full-time
        'M_d': 0,        # Số lượng tài xế loại này
        'work_time': T_MAX * 0.5625  # 4.5 giờ
    },
    {
        'id': 5,
        'name': 'Part-time (50%)',
        'r_d': 0.5,      # 50% thời gian full-time
        'M_d': 0,        # Số lượng tài xế loại này
        'work_time': T_MAX * 0.5  # 4.0 giờ
    }
]

# Tạo danh sách tài xế cụ thể từ DRIVER_TYPES
DRIVERS = []
driver_id = 0
driver_names = ['1','2'] 

for dtype in DRIVER_TYPES:
    for _ in range(dtype['M_d']):
        DRIVERS.append({
            'id': driver_id,
            'name': driver_names[driver_id] if driver_id < len(driver_names) else f"Driver {driver_id}",
            'type': dtype['name'],
            'type_id': dtype['id'],
            'r_d': dtype['r_d'],
            'work_time': dtype['work_time'],
            'priority': dtype['id']  # Loại 1 (full-time) có priority cao nhất
        })
        driver_id += 1

# =============================================================================
# VEHICLE TYPES - V = {1, ..., |V|}
# =============================================================================
# Định nghĩa các loại xe theo paper
VEHICLE_TYPES = [
    {
        'id': 1,
        'name': 'Xe máy to',
        'C_v': 20,     
        'N_v': 2      
    },
    {
        'id': 2,
        'name': 'Xe máy vừa',
        'C_v': 15,  
        'N_v': 0       
    },
    {
        'id': 3,
        'name': 'Xe máy nhỏ',
        'C_v': 10,    
        'N_v': 0
         
    }
]

# Tạo danh sách xe cụ thể từ VEHICLE_TYPES
VEHICLES = []
vehicle_id = 0
for vtype in VEHICLE_TYPES:
    for _ in range(vtype['N_v']):
        VEHICLES.append({
            'id': vehicle_id,
            'type': vtype['name'],
            'type_id': vtype['id'],
            'capacity': vtype['C_v'],
            'priority': vtype['id']  
        })
        vehicle_id += 1

# Tính tổng số tài nguyên
TOTAL_DRIVERS = sum(dt['M_d'] for dt in DRIVER_TYPES)
TOTAL_VEHICLES = sum(vt['N_v'] for vt in VEHICLE_TYPES)

# Số lượng quận tối đa = min(số tài xế, số xe)
MAX_DISTRICTS = min(TOTAL_DRIVERS, TOTAL_VEHICLES)
MIN_DISTRICTS = 1
NUM_DISTRICTS = MAX_DISTRICTS  # Bắt đầu với max, có thể tối ưu sau

print(f" Đã cấu hình:")
print(f"   - Driver types: {len(DRIVER_TYPES)} loại, tổng {TOTAL_DRIVERS} tài xế")
print(f"   - Vehicle types: {len(VEHICLE_TYPES)} loại, tổng {TOTAL_VEHICLES} xe")
print(f"   - Số quận: {MIN_DISTRICTS}-{MAX_DISTRICTS}")

# =============================================================================
# HÀM TẠO DỮ LIỆU KHU VỰC VÀ NHU CẦU
# =============================================================================

def generate_areas_with_demand(num_areas, map_size, parcels_range=(10, 20)):
    areas = []
    random.seed(42)  # Seed cố định để vị trí không đổi
    
    for i in range(num_areas):
        # Tạo nhu cầu ngẫu nhiên cho mỗi khu vực
        parcels = random.randint(*parcels_range)
        workload = round(random.uniform(0.1, 0.2), 2)  # Workload dựa trên số bưu kiện
        weight = round(random.uniform(0.5, 4), 2)  # Trọng lượng trung bình
        
        areas.append({
            'id': i,
            'x': random.randint(0, map_size),
            'y': random.randint(0, map_size),
            'parcels': parcels,
            'workload': workload,
            'weight': weight
        })
    
    random.seed()
    return areas
# Out:
#  Đã cấu hình:
#    - Driver types: 5 loại, tổng 2 tài xế
#    - Vehicle types: 3 loại, tổng 2 xe
#    - Số quận: 1-2

# %%
# =============================================================================
# 2. HÀM GÁN TÀI NGUYÊN THEO THỨ TỰ ƯU TIÊN (PRIORITY-BASED ASSIGNMENT)
# =============================================================================

def assign_resources_with_priority(district_stats):
    # Sắp xếp quận theo workload (cao → thấp)
    sorted_districts = sorted(district_stats, key=lambda x: x['workload'], reverse=True)
    
    # Sắp xếp drivers theo priority (1 → 2) và work_time (cao → thấp)
    sorted_drivers = sorted(DRIVERS, key=lambda x: (x['priority'], -x['work_time']))
    
    # Sắp xếp vehicles theo priority (1 → 2 → 3) và capacity (cao → thấp)
    sorted_vehicles = sorted(VEHICLES, key=lambda x: (x['priority'], -x['capacity']))
    
    assignments = {}
    used_drivers = []
    used_vehicles = []
    
    for i, district in enumerate(sorted_districts):
        district_id = district['id']
        
        # Tìm driver phù hợp chưa được dùng
        driver = None
        for d in sorted_drivers:
            if d['id'] not in used_drivers:
                driver = d
                used_drivers.append(d['id'])
                break
        
        # Tìm vehicle phù hợp chưa được dùng
        vehicle = None
        for v in sorted_vehicles:
            if v['id'] not in used_vehicles:
                vehicle = v
                used_vehicles.append(v['id'])
                break
        
        if driver is None or vehicle is None:
            # Không đủ tài nguyên
            return None, False
        
        assignments[district_id] = {
            'driver': driver,
            'vehicle': vehicle,
            'workload': district['workload'],
            'parcels': district['parcels'],
            'weight': district['weight']
        }
    
    return assignments, True

def calculate_total_time(solution, areas, assignments):
    """
    Tính tổng thời gian làm việc của mỗi quận bao gồm:
    - Thời gian di chuyển: Depot => Tâm quận => Các điểm => Tâm quận => Depot (mỗi chuyến)
    - Thời gian phục vụ (workload)
    - Thời gian nạp lại hàng (reload time)
    """
    centers = calculate_district_centers(solution, areas)
    district_times = {}
    
    for district_id in range(NUM_DISTRICTS):
        # ⚠️ SỬA LỖI: Tính số chuyến dựa vào TRỌNG LƯỢNG, không phải số bưu kiện
        total_weight = assignments[district_id]['weight']
        vehicle_capacity = assignments[district_id]['vehicle']['capacity']
        
        # Tính số chuyến cần thiết DỰA VÀO TRỌNG LƯỢNG
        num_trips = math.ceil(total_weight / vehicle_capacity) if vehicle_capacity > 0 else 1
        
        # Tính khoảng cách depot → tâm quận
        depot_pos = np.array([DEPOT['x'], DEPOT['y']])
        center_pos = centers[district_id]
        distance_depot_to_center = np.linalg.norm(depot_pos - center_pos)
        
        # Tính tổng khoảng cách từ tâm quận đến các điểm trong quận
        distance_within_district = 0
        for area_idx, dist_id in enumerate(solution):
            if dist_id == district_id:
                area_pos = np.array([areas[area_idx]['x'], areas[area_idx]['y']])
                distance_within_district += np.linalg.norm(area_pos - center_pos)
        
        # Tổng quãng đường mỗi chuyến:
        # Depot → Tâm quận → Các điểm (distance_within_district) → Tâm quận → Depot
        distance_per_trip = distance_depot_to_center + distance_within_district

        if(num_trips>1):
            distance_per_trip = distance_per_trip + distance_depot_to_center * (num_trips - 1) * 2 
        
        # Tổng thời gian di chuyển cho tất cả các chuyến
        total_travel_time = distance_per_trip / TRAVEL_SPEED

        
        
        # Thời gian nạp lại hàng (chuyến đầu không cần reload)
        reload_time = (num_trips - 1) * RELOAD_TIME if num_trips > 1 else 0
        
        # Thời gian phục vụ
        service_time = sum(areas[i]['workload'] for i, d in enumerate(solution) if d == district_id)
        
        # Tổng thời gian
        district_times[district_id] = total_travel_time + reload_time + service_time

        print(f" Quận {district_id}: Tổng quãng đường={distance_per_trip/10:.2f}km, Thời gian di chuyển={total_travel_time:.2f}h")
        print(f" Quận {district_id}: {total_travel_time:.2f} (di chuyển) + {reload_time:.2f} (nạp lại) + {service_time:.2f} (phục vụ) = {district_times[district_id]:.2f}h")
    
    return district_times

# =============================================================================
# 3. HÀM MỤC TIÊU VÀ HÀM HỖ TRỢ (ĐÃ ĐỒNG BỘ VỚI DỮ LIỆU ĐẦU VÀO MỚI)
# =============================================================================

def calculate_district_centers(solution, areas):
    """ Tính toán tâm địa lý của mỗi quận."""
    centers = np.zeros((NUM_DISTRICTS, 2))
    counts = np.zeros(NUM_DISTRICTS)
    
    for area_idx, district_id in enumerate(solution):
        centers[district_id, 0] += areas[area_idx]['x']
        centers[district_id, 1] += areas[area_idx]['y']
        counts[district_id] += 1
    
    # Tránh chia cho 0
    counts[counts == 0] = 1
    centers[:, 0] /= counts
    centers[:, 1] /= counts
    
    return centers

def calculate_objective_function_with_resources(solution, areas):
    
    # Tính toán đặc tính của mỗi quận
    district_stats = [{'workload': 0, 'parcels': 0, 'weight': 0, 'id': i} 
                      for i in range(NUM_DISTRICTS)]
    
    for area_idx, district_id in enumerate(solution):
        district_stats[district_id]['workload'] += areas[area_idx]['workload']
        district_stats[district_id]['parcels'] += areas[area_idx]['parcels']
        if 'weight' in areas[area_idx]:
            district_stats[district_id]['weight'] += areas[area_idx]['weight']

    # Gán tài xế và xe theo thứ tự ưu tiên
    assignments, is_valid = assign_resources_with_priority(district_stats)
    
    if not is_valid:
        # Không đủ tài nguyên → điểm rất cao (solution không khả thi)
        return 1000000
    
    # Tính tâm quận
    centers = calculate_district_centers(solution, areas)
    
    # =========================================================================
    # 1. BALANCE SCORE - Cân bằng workload theo tỷ lệ sử dụng
    # =========================================================================
    # So sánh TỶ LỆ sử dụng capacity giữa các driver
    utilization_rates = []
    for i in range(NUM_DISTRICTS):
        driver_capacity = assignments[i]['driver']['work_time']
        actual_workload = district_stats[i]['workload']
        
        # Tỷ lệ sử dụng = workload / work_time
        utilization_rate = actual_workload / driver_capacity if driver_capacity > 0 else 0
        utilization_rates.append(utilization_rate)
    
    # Tính độ lệch chuẩn của các tỷ lệ sử dụng (càng nhỏ càng cân bằng)
    mean_utilization = np.mean(utilization_rates)
    balance_score = sum((rate - mean_utilization) ** 2 for rate in utilization_rates) / NUM_DISTRICTS
    
    # =========================================================================
    # 2. COMPACTNESS SCORE - Độ nhỏ gọn
    # =========================================================================
    # Tổng khoảng cách từ các khu vực đến tâm quận của chúng
    compactness_score = 0
    for area_idx, district_id in enumerate(solution):
        area_pos = np.array([areas[area_idx]['x'], areas[area_idx]['y']])
        center_pos = centers[district_id]
        compactness_score += np.linalg.norm(area_pos - center_pos)
    
    # =========================================================================
    # 3. TIME PENALTY & BALANCE TIME - Tính tổng thời gian cho mỗi quận
    # =========================================================================
    # SỬ DỤNG HÀM calculate_total_time ĐÃ CÓ SẴN để tính tổng thời gian
    district_times = calculate_total_time(solution, areas, assignments)
    
    time_penalty = 0
    time_utilization_rates = []
    
    for i in range(NUM_DISTRICTS):
        driver_time_limit = assignments[i]['driver']['work_time']
        total_time = district_times[i]
        
        # Tính tỷ lệ thời gian sử dụng cho BALANCE TIME
        time_ratio = total_time / driver_time_limit if driver_time_limit > 0 else 0
        time_utilization_rates.append(time_ratio)
        
        # Phạt nếu vượt thời gian cho TIME PENALTY
        if total_time > driver_time_limit:
            excess = total_time - driver_time_limit
            excess_ratio = excess / driver_time_limit
            # Phạt theo bình phương để tăng nhanh khi vi phạm nhiều
            time_penalty += (excess_ratio) * 10000
    
    # Tính độ lệch chuẩn của tỷ lệ thời gian (càng nhỏ càng cân bằng) cho BALANCE TIME
    mean_time_utilization = np.mean(time_utilization_rates)
    balance_time_score = (sum((rate - mean_time_utilization) ** 2 for rate in time_utilization_rates) / NUM_DISTRICTS) * 10
    
    # =========================================================================
    # CHUẨN HÓA VÀ KẾT HỢP ĐIỂM
    # =========================================================================
    # Chuẩn hóa balance score
    mean_work_time = np.mean([d['work_time'] for d in DRIVERS])
    normalized_balance = balance_score / (mean_work_time ** 2) if mean_work_time > 0 else 0
    
    # Chuẩn hóa balance time score
    normalized_balance_time = balance_time_score  # Đã là tỷ lệ, không cần chuẩn hóa thêm
    
    # Chuẩn hóa compactness score
    normalized_compactness = compactness_score / (len(areas) * MAP_SIZE)

    BALANCE_WEIGHT = 0.3
    BALANCE_TIME_WEIGHT = 0.3
    COMPACTNESS_WEIGHT = 0.3   
    TIME_PENALTY_WEIGHT = 0.1
    
    total_score = (BALANCE_WEIGHT * normalized_balance + 
                   BALANCE_TIME_WEIGHT * normalized_balance_time +
                   COMPACTNESS_WEIGHT * normalized_compactness + 
                   TIME_PENALTY_WEIGHT * time_penalty)
    
    return total_score

# %%
# =============================================================================
# 1B. THÊM RÀNG BUỘC LIỀN MẠCH (CONTIGUOUS CONSTRAINT)
# =============================================================================

def build_neighbor_graph(areas, threshold= 7.6):
    """ Xây dựng đồ thị lân cận: hai khu vực là "hàng xóm" nếu khoảng cách < threshold. """
    neighbor_graph = {i: [] for i in range(len(areas))}
    
    for i in range(len(areas)):
        for j in range(i + 1, len(areas)):
            dist = np.linalg.norm(
                np.array([areas[i]['x'], areas[i]['y']]) - 
                np.array([areas[j]['x'], areas[j]['y']])
            )
            if dist <= threshold:
                neighbor_graph[i].append(j)
                neighbor_graph[j].append(i)
    
    return neighbor_graph

def is_contiguous(solution, neighbor_graph, district_id):
    """
    Kiểm tra xem một quận có liền mạch (contiguous) không.
    
    Phương pháp: Sử dụng BFS/DFS để kiểm tra tất cả khu vực trong quận có thể 
    đến được nhau thông qua các khu vực lân cận cùng quận hay không.
    """
    # Lấy danh sách các khu vực thuộc quận này
    district_areas = [i for i, d in enumerate(solution) if d == district_id]
    
    if len(district_areas) == 0:
        return True  # Quận rỗng coi như hợp lệ
    
    if len(district_areas) == 1:
        return True  # Chỉ có 1 khu vực thì luôn liền mạch
    
    # BFS để kiểm tra connectivity
    visited = set()
    queue = [district_areas[0]]  # Bắt đầu từ khu vực đầu tiên
    visited.add(district_areas[0])
    
    while queue:
        current = queue.pop(0)
        
        # Duyệt các hàng xóm của khu vực hiện tại
        for neighbor in neighbor_graph[current]:
            # Chỉ xét hàng xóm cũng thuộc cùng quận và chưa được thăm
            if neighbor in district_areas and neighbor not in visited:
                visited.add(neighbor)
                queue.append(neighbor)
    
    # Nếu tất cả khu vực đều được thăm thì quận liền mạch
    return len(visited) == len(district_areas)

def check_all_contiguous(solution, neighbor_graph):
    """Kiểm tra tất cả các quận có liền mạch không."""
    for district_id in range(NUM_DISTRICTS):
        if not is_contiguous(solution, neighbor_graph, district_id):
            return False
    return True

def repair_contiguous(solution, neighbor_graph):
    """
    Sửa lỗi liền mạch bằng cách gán lại các khu vực bị tách rời 
    vào quận của hàng xóm gần nhất.
    """
    max_iterations = 50
    iteration = 0
    
    while iteration < max_iterations:
        all_contiguous = True
        
        for district_id in range(NUM_DISTRICTS):
            if not is_contiguous(solution, neighbor_graph, district_id):
                all_contiguous = False
                
                # Tìm các khu vực bị tách rời và gán lại
                district_areas = [i for i, d in enumerate(solution) if d == district_id]
                
                if len(district_areas) == 0:
                    continue
                
                # BFS để tìm connected component lớn nhất
                visited = set()
                queue = [district_areas[0]]
                visited.add(district_areas[0])
                
                while queue:
                    current = queue.pop(0)
                    for neighbor in neighbor_graph[current]:
                        if neighbor in district_areas and neighbor not in visited:
                            visited.add(neighbor)
                            queue.append(neighbor)
                
                # Các khu vực không trong component lớn nhất → gán lại
                isolated_areas = [a for a in district_areas if a not in visited]
                
                for area in isolated_areas:
                    # Tìm quận của hàng xóm gần nhất
                    neighbor_districts = [solution[n] for n in neighbor_graph[area] if solution[n] != district_id]
                    if neighbor_districts:
                        # Gán vào quận xuất hiện nhiều nhất trong hàng xóm
                        
                        most_common = Counter(neighbor_districts).most_common(1)[0][0]
                        solution[area] = most_common
        
        if all_contiguous:
            break
        
        iteration += 1
    
    return solution

# %%
# =============================================================================
# 3. CÁC THUẬT TOÁN 
# =============================================================================

### 3A. Local Search ###
def local_search(initial_solution, areas, use_contiguity=True):
    current_solution = list(initial_solution)
    current_score = calculate_objective_function_with_resources(current_solution, areas)
    
    # LƯU LẠI điểm ban đầu để đảm bảo không trả về solution tệ hơn
    initial_score = current_score
    best_solution = list(current_solution)
    best_score = current_score
    
    # Xây dựng đồ thị lân cận nếu cần kiểm tra contiguity
    neighbor_graph = None
    if use_contiguity:
        neighbor_graph = build_neighbor_graph(areas)  # Giảm threshold cho bản đồ nhỏ
    
    improved = True
    iteration = 0
    max_iterations = max(20, 10000/len(areas))   # Giới hạn số vòng lặp
    
    while improved and iteration < max_iterations:
        improved = False
        best_neighbor_solution = list(current_solution)
        
        for area_idx in range(len(areas)):
            original_district = current_solution[area_idx]
            for new_district in range(NUM_DISTRICTS):
                if new_district == original_district: 
                    continue
                
                # Tạo solution mới
                neighbor_solution = list(current_solution)
                neighbor_solution[area_idx] = new_district
                
                # Kiểm tra contiguity nếu được bật
                if use_contiguity and neighbor_graph:
                    # Kiểm tra cả 2 quận: quận cũ và quận mới
                    if not is_contiguous(neighbor_solution, neighbor_graph, original_district):
                        continue  # Bỏ qua nếu quận cũ bị phá vỡ
                    if not is_contiguous(neighbor_solution, neighbor_graph, new_district):
                        continue  # Bỏ qua nếu quận mới không liền mạch
                
                # Tính điểm
                neighbor_score = calculate_objective_function_with_resources(neighbor_solution, areas)
                
                if neighbor_score < current_score:
                    best_neighbor_solution = neighbor_solution
                    current_score = neighbor_score
                    improved = True
                    break 
            if improved:
                break
        
        current_solution = best_neighbor_solution
        iteration += 1
        
        # Cập nhật best nếu tốt hơn
        if current_score < best_score:
            best_solution = list(current_solution)
            best_score = current_score
    
    # Sửa lỗi contiguity cuối cùng nếu cần
    if use_contiguity and neighbor_graph:
        repaired_solution = repair_contiguous(list(current_solution), neighbor_graph)
        repaired_score = calculate_objective_function_with_resources(repaired_solution, areas)
        
        # CHỈ chấp nhận repaired solution nếu tốt hơn hoặc bằng best
        if repaired_score <= best_score:
            best_solution = repaired_solution
            best_score = repaired_score
    
    # ĐẢM BẢO không trả về solution tệ hơn initial
    if best_score > initial_score:
        print(f" Warning: LS không cải thiện được (initial: {initial_score:.4f}, best: {best_score:.4f})")
        return list(initial_solution), initial_score
    
    return best_solution, best_score

# %%
### 3B. Variable Neighborhood Search (VNS) với Contiguity ###
def shake(solution, k):
    """Hàm "lắc" để thoát khỏi tối ưu cục bộ - Di chuyển 20% khu vực của 1 quận ngẫu nhiên, lặp k lần."""
    new_solution = list(solution)
    
    # Lặp k lần để thực hiện shake mạnh hơn
    for _ in range(k):
        # Chọn ngẫu nhiên 1 quận để shake
        district_to_shake = random.randint(0, NUM_DISTRICTS - 1)
        
        # Lấy danh sách các khu vực thuộc quận này
        areas_in_district = [i for i, d in enumerate(new_solution) if d == district_to_shake]
        
        if len(areas_in_district) == 0:
            continue
        
        # Số khu vực để di chuyển (20%)
        num_areas_to_move = max(1, int(len(areas_in_district) * 0.20))
        
        # Chọn ngẫu nhiên các khu vực để di chuyển
        areas_to_move = random.sample(areas_in_district, min(num_areas_to_move, len(areas_in_district)))
        
        # Di chuyển các khu vực sang quận khác
        for area_idx in areas_to_move:
            # Chọn quận đích khác với quận hiện tại
            new_district = random.randint(0, NUM_DISTRICTS - 1)
            while new_district == district_to_shake and NUM_DISTRICTS > 1:
                new_district = random.randint(0, NUM_DISTRICTS - 1)
            new_solution[area_idx] = new_district
    
    return new_solution

def vns(initial_solution, areas, max_iter=4, k_max=5, use_contiguity=True):
    """VNS với kiểm tra liền mạch."""
    best_solution = list(initial_solution)
    best_score = calculate_objective_function_with_resources(best_solution, areas)
    
    # Xây dựng đồ thị lân cận
    neighbor_graph = None
    if use_contiguity:
        neighbor_graph = build_neighbor_graph(areas)

    for i in range(max_iter):
        k = 3
        while k <= k_max:
            shaken_solution = shake(best_solution, k)
            
            # Sửa contiguity cho solution sau khi shake
            if use_contiguity and neighbor_graph:
                shaken_solution = repair_contiguous(shaken_solution, neighbor_graph)
            
            improved_solution, improved_score = local_search(shaken_solution, areas, use_contiguity)
            
            if improved_score < best_score:
                best_solution = improved_solution
                best_score = improved_score
                print(f"VNS Iter {i}, k={k}: Found new best score = {best_score:.4f}")
                k = 3
            else:
                k += 3    
    return best_solution, best_score

# %%
# =============================================================================
# 4. TRỰC QUAN HÓA VÀ CHẠY CHƯƠNG TRÌNH
# =============================================================================

def plot_solution(solution, areas, title, show_depot=True):
    """Vẽ biểu đồ phân chia các khu vực."""
    plt.figure(figsize=(14, 12))
    colors = plt.cm.get_cmap('nipy_spectral', NUM_DISTRICTS)
    
    # Vẽ depot
    if show_depot:
        plt.scatter(DEPOT['x'], DEPOT['y'], color='black', marker='s', s=500, 
                   label='KHO HÀNG (DEPOT)', zorder=5, edgecolors='yellow', linewidths=3)
    
    # Vẽ các khu vực
    for area_idx, district_id in enumerate(solution):
        area = areas[area_idx]
        plt.scatter(area['x'], area['y'], color=colors(district_id), 
                   s=area['parcels']*10, alpha=0.85, edgecolors='black', linewidths=1)
    
    # Vẽ tâm các quận 
    centers = calculate_district_centers(solution, areas)
    for i in range(NUM_DISTRICTS):
        plt.scatter(centers[i, 0], centers[i, 1], color='red', marker='X', 
                   s=600, linewidths=4, label=f'Tâm Quận {i}' if i == 0 else '', 
                   edgecolors='white', zorder=4)

    plt.title(title, fontsize=14, fontweight='bold')
    plt.xlabel("Tọa độ X"); plt.ylabel("Tọa độ Y")
    plt.legend(loc='upper right')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

def assign_resources_to_districts(solution, areas):
    """
    Gán driver và vehicle riêng biệt cho từng quận theo thứ tự ưu tiên.
    """
    # Tính thống kê cho từng quận
    district_stats = [{'workload': 0, 'parcels': 0, 'weight': 0, 'id': i, 'area_count': 0} 
                     for i in range(NUM_DISTRICTS)]
    
    for area_idx, district_id in enumerate(solution):
        district_stats[district_id]['workload'] += areas[area_idx]['workload']
        district_stats[district_id]['parcels'] += areas[area_idx]['parcels']
        district_stats[district_id]['weight'] += areas[area_idx]['weight']
        district_stats[district_id]['area_count'] += 1
    
    # Sử dụng hàm gán tài nguyên theo thứ tự ưu tiên
    assignments, is_valid = assign_resources_with_priority(district_stats)
    
    if not is_valid:
        print("  CẢNH BÁO: Không đủ tài nguyên để gán!")
        return None, district_stats
    
    for i in range(NUM_DISTRICTS):
        assignments[i]['area_count'] = district_stats[i]['area_count']
        assignments[i]['weight'] = district_stats[i]['weight']
    
    return assignments, district_stats

def print_strategic_plan(solution, areas, assignments, algorithm_name):
    """In kết quả Giai đoạn 1: Kế hoạch Chiến thuật."""
    
    if assignments is None:
        print("\n  Không thể in kế hoạch: Không đủ tài nguyên!")
        return
    
    print("\n" + "="*80)
    print(f" KẾ HOẠCH CHIẾN THUẬT - Thuật toán: {algorithm_name}")
    print("="*80)
    
    # Tính tổng quãng đường và thời gian cho từng quận
    centers = calculate_district_centers(solution, areas)
    district_distances = {}
    
    for district_id in range(NUM_DISTRICTS):
        total_distance = 0
        # Khoảng cách từ depot đến tâm quận
        depot_to_center = np.linalg.norm(np.array([DEPOT['x'], DEPOT['y']]) - centers[district_id])
        
        # Khoảng cách từ các khu vực đến tâm quận
        for area_idx, dist_id in enumerate(solution):
            if dist_id == district_id:
                area_pos = np.array([areas[area_idx]['x'], areas[area_idx]['y']])
                center_pos = centers[district_id]
                total_distance += np.linalg.norm(area_pos - center_pos)
        
        # Ước lượng tổng quãng đường
        district_distances[district_id] = depot_to_center * 2 + total_distance
    
    # Tính tổng thời gian cho từng quận (sử dụng hàm calculate_total_time)
    total_times = calculate_total_time(solution, areas, assignments)
    
    # In bảng tổng quan
    print(f"\n{'='*160}")
    print(f"BẢNG TỔNG QUAN PHÂN CÔNG")
    print(f"{'='*160}")
    print(f"{'Quận':<6} {'Tài xế':<16} {'Loại':<20} {'Xe':<16} {'Khu vực':<10} "
          f"{'Tổng TG/Time':<16} {'Bưu kiện/h':<14} {'Trọng lượng':<18} {'Chuyến':<8} {'Tỷ lệ sử dụng':<15}")
    print("-" * 160)
    
    for district_id in range(NUM_DISTRICTS):
        assign = assignments[district_id]
        driver = assign['driver']
        vehicle = assign['vehicle']
        total_time = total_times[district_id]
        
        # Tính số chuyến dựa trên trọng lượng
        num_trips = math.ceil(assign['weight'] / vehicle['capacity']) if vehicle['capacity'] > 0 else 1
        
        # Format total time / work time
        time_str = f"{total_time:.2f}/{driver['work_time']:.1f}h"
        
        # Tính số bưu kiện/giờ cho quận này
        parcels_per_hour_district = assign['parcels'] / total_time if total_time > 0 else 0
        parcels_str = f"{parcels_per_hour_district:.1f} pcs/h"
        
        # Format weight/capacity (kg)
        weight_str = f"{assign['weight']:.1f}/{vehicle['capacity']} kg"
        
        # Format trips
        trips_str = f"{num_trips}x"
        
        # Tính tỷ lệ sử dụng
        utilization_rate = (total_time / driver['work_time'] * 100) if driver['work_time'] > 0 else 0
        utilization_str = f"{utilization_rate:.1f}%"
        
        # # Đánh dấu vi phạm (nếu total_time > work_time)
        time_mark = " ⚠️" if total_time > driver['work_time'] else " "
        
        print(f"{district_id:<6} {driver['name']:<16} {driver['type']:<20} "
              f"{vehicle['type']:<16} {assign['area_count']:<10} "
              f"{time_str:<12}{time_mark:<4} {parcels_str:<14} {weight_str:<18} {trips_str:<8} "
              f"{utilization_str:<15}")
    
    # In thống kê tổng hợp
    print("-" * 160)
    total_workload = sum([assignments[i]['workload'] for i in range(NUM_DISTRICTS)])
    total_parcels = sum([assignments[i]['parcels'] for i in range(NUM_DISTRICTS)])
    total_weight = sum([assignments[i]['weight'] for i in range(NUM_DISTRICTS)])
    total_time_all = sum(total_times.values())
    
    # Tính số bưu kiện/giờ
    parcels_per_hour = total_parcels / total_time_all if total_time_all > 0 else 0
    
    print(f"{'TỔNG CỘNG':<50} "
          f"Workload: {total_workload:.2f}h  |  Bưu kiện/h: {parcels_per_hour:.1f}  |  Trọng lượng: {total_weight:.1f}kg  |  Tổng TG: {total_time_all:.2f}h")
    print("=" * 160)

# %%
def generate_random_solution(num_areas, num_districts):
    """
    Tạo một lời giải ban đầu với các khu vực liền mạch được chia đều cho các quận.
    Sử dụng thuật toán phân cụm theo vị trí địa lý.
    """
    # Tạo danh sách khu vực với tọa độ
    areas_temp = generate_areas_with_demand(num_areas, MAP_SIZE)
    
    # Sắp xếp khu vực theo tọa độ (x, sau đó y) để các khu vực gần nhau được nhóm lại
    sorted_indices = sorted(range(num_areas), 
                           key=lambda i: (areas_temp[i]['x'] // 10, areas_temp[i]['y'] // 10))
    
    solution = [-1] * num_areas
    areas_per_district = num_areas // num_districts
    extra_areas = num_areas % num_districts
    
    # Gán khu vực tuần tự cho từng quận theo thứ tự đã sắp xếp
    current_index = 0
    for district_id in range(num_districts):
        count = areas_per_district + (1 if district_id < extra_areas else 0)
        for _ in range(count):
            solution[sorted_indices[current_index]] = district_id
            current_index += 1
    
    return solution

# %%
# =============================================================================
# BƯỚC 1: CHUẨN BỊ DỮ LIỆU
# =============================================================================
# Tạo khu vực với nhu cầu trung bình
print(f"\n   Tạo {NUM_BASIC_AREAS} khu vực với nhu cầu trung bình...")
areas = generate_areas_with_demand(NUM_BASIC_AREAS, MAP_SIZE)


# Tạo lời giải ban đầu
print("\n Tạo lời giải ban đầu ngẫu nhiên...")
initial_solution = generate_random_solution(NUM_BASIC_AREAS, NUM_DISTRICTS)
initial_score = calculate_objective_function_with_resources(initial_solution, areas)
print(f"   → Điểm ban đầu: {initial_score:.4f}")

# Gán tài xế và xe cho lời giải ban đầu
initial_assignments, initial_stats = assign_resources_to_districts(initial_solution, areas)
# Out:
#    Tạo 50 khu vực với nhu cầu trung bình...
#
#  Tạo lời giải ban đầu ngẫu nhiên...
#  Quận 0: Tổng quãng đường=24.53km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.86 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=20.07km, Thời gian di chuyển=0.40h
#  Quận 1: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.39h
#    → Điểm ban đầu: 0.0921

# %%
print_strategic_plan(initial_solution, areas, initial_assignments, "RANDOM (Lời giải ban đầu)")

# Vẽ biểu đồ cho lời giải ban đầu
print("\nTrực quan hóa lời giải ban đầu...")
plot_solution(initial_solution, areas, 
             f"RANDOM (Lời giải ban đầu) - Score: {initial_score:.4f}")
# Out:
# ================================================================================
#  KẾ HOẠCH CHIẾN THUẬT - Thuật toán: RANDOM (Lời giải ban đầu)
# ================================================================================
#  Quận 0: Tổng quãng đường=24.53km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.86 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=20.07km, Thời gian di chuyển=0.40h
#  Quận 1: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.39h
#
# ================================================================================================================================================================
# BẢNG TỔNG QUAN PHÂN CÔNG
# ================================================================================================================================================================
# Quận   Tài xế           Loại                 Xe               Khu vực    Tổng TG/Time     Bưu kiện/h     Trọng lượng        Chuyến   Tỷ lệ sử dụng
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# 0      1                Full-time            Xe máy to        25         5.10/8.0h        71.0 pcs/h     66.7/20 kg         4x       63.8%
# 1      2                Full-time            Xe máy to        25         4.39/8.0h        78.1 pcs/h     51.5/20 kg         3x       54.9%
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# TỔNG CỘNG                                          Workload: 7.35h  |  Bưu kiện/h: 74.3  |  Trọng lượng: 118.1kg  |  Tổng TG: 9.49h
# ================================================================================================================================================================
#
# Trực quan hóa lời giải ban đầu...
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13540\4021880790.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('nipy_spectral', NUM_DISTRICTS)

# %% [markdown]
# ### Local Search với 1 phần tử

# %%
print("\n" + "="*80)
print("THUẬT TOÁN 1: LOCAL SEARCH")
print("="*80)

ls_solution, ls_score = local_search(initial_solution, areas)

print(f"\nKết quả Local Search:")
print(f" → Điểm tốt nhất: {ls_score:.4f}")
print(f" → Cải thiện: {((initial_score - ls_score) / initial_score * 100):.1f}%")

ls_assignments, ls_stats = assign_resources_to_districts(ls_solution, areas)

print("\nTrực quan hóa Local Search...")
plot_solution(ls_solution, areas, 
             f"LOCAL SEARCH - Score: {ls_score:.4f}")
# Out:
# ================================================================================
# THUẬT TOÁN 1: LOCAL SEARCH
# ================================================================================
#  Quận 0: Tổng quãng đường=24.53km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.86 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=20.07km, Thời gian di chuyển=0.40h
#  Quận 1: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.39h
#  Quận 0: Tổng quãng đường=24.21km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.75 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=21.28km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.60 (phục vụ) = 4.53h
#  Quận 0: Tổng quãng đường=24.53km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.86 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=20.07km, Thời gian di chuyển=0.40h
#  Quận 1: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.39h
#  Quận 0: Tổng quãng đường=23.03km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.58 (phục vụ) = 4.79h
#  Quận 1: Tổng quãng đường=22.60km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.77 (phục vụ) = 4.72h
#  Quận 0: Tổng quãng đường=23.37km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.69 (phục vụ) = 4.91h
#  Quận 1: Tổng quãng đường=21.40km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.66 (phục vụ) = 4.59h
#  Quận 0: Tổng quãng đường=23.03km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.58 (phục vụ) = 4.79h
#  Quận 1: Tổng quãng đường=22.60km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.77 (phục vụ) = 4.72h
#  Quận 0: Tổng quãng đường=24.53km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.86 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=20.07km, Thời gian di chuyển=0.40h
#  Quận 1: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.39h
#  Quận 0: Tổng quãng đường=23.00km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.55 (phục vụ) = 4.76h
#  Quận 1: Tổng quãng đường=22.67km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.80 (phục vụ) = 4.75h
#  Quận 0: Tổng quãng đường=21.96km, Thời gian di chuyển=0.44h
#  Quận 0: 0.44 (di chuyển) + 0.75 (nạp lại) + 3.55 (phục vụ) = 4.74h
#  Quận 1: Tổng quãng đường=22.64km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.80 (phục vụ) = 4.75h
#  Quận 0: Tổng quãng đường=20.28km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.35h
#  Quận 1: Tổng quãng đường=23.85km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.91 (phục vụ) = 4.89h
#  Quận 0: Tổng quãng đường=23.09km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.72 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=21.34km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.63 (phục vụ) = 4.56h
#  Quận 0: Tổng quãng đường=21.65km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.41 (phục vụ) = 4.59h
#  Quận 1: Tổng quãng đường=23.92km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.94 (phục vụ) = 4.92h
#  Quận 0: Tổng quãng đường=23.37km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.69 (phục vụ) = 4.91h
#  Quận 1: Tổng quãng đường=21.40km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.66 (phục vụ) = 4.59h
#  Quận 0: Tổng quãng đường=22.45km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.73 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=22.00km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.62 (phục vụ) = 4.56h
#  Quận 0: Tổng quãng đường=19.82km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.43 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=24.89km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.92 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=19.42km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.37 (phục vụ) = 4.26h
#  Quận 1: Tổng quãng đường=23.85km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.98 (phục vụ) = 4.96h
#  Quận 0: Tổng quãng đường=19.86km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.37 (phục vụ) = 4.27h
#  Quận 1: Tổng quãng đường=25.02km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.98 (phục vụ) = 5.23h
#  Quận 0: Tổng quãng đường=19.95km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.42 (phục vụ) = 4.32h
#  Quận 1: Tổng quãng đường=23.77km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.93 (phục vụ) = 4.91h
#  Quận 0: Tổng quãng đường=22.28km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.67 (phục vụ) = 4.87h
#  Quận 1: Tổng quãng đường=21.90km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.68 (phục vụ) = 4.62h
#  Quận 0: Tổng quãng đường=20.62km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.56 (phục vụ) = 4.47h
#  Quận 1: Tổng quãng đường=23.13km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.79 (phục vụ) = 4.75h
#  Quận 0: Tổng quãng đường=23.41km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.84 (phục vụ) = 5.06h
#  Quận 1: Tổng quãng đường=20.60km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.51 (phục vụ) = 4.42h
#  Quận 0: Tổng quãng đường=21.95km, Thời gian di chuyển=0.44h
#  Quận 0: 0.44 (di chuyển) + 0.75 (nạp lại) + 3.53 (phục vụ) = 4.72h
#  Quận 1: Tổng quãng đường=23.20km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.82 (phục vụ) = 4.78h
#  Quận 0: Tổng quãng đường=23.66km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.81 (phục vụ) = 5.03h
#  Quận 1: Tổng quãng đường=20.67km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.54 (phục vụ) = 4.45h
#  Quận 0: Tổng quãng đường=22.76km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.85 (phục vụ) = 5.06h
#  Quận 1: Tổng quãng đường=21.25km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.42h
#  Quận 0: Tổng quãng đường=20.16km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.45h
#  Quận 1: Tổng quãng đường=23.27km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.80 (phục vụ) = 4.77h
#  Quận 0: Tổng quãng đường=19.78km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.39h
#  Quận 1: Tổng quãng đường=23.12km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.86 (phục vụ) = 4.82h
#  Quận 0: Tổng quãng đường=20.19km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.39h
#  Quận 1: Tổng quãng đường=23.42km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.86 (phục vụ) = 4.83h
#  Quận 0: Tổng quãng đường=20.30km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.54 (phục vụ) = 4.45h
#  Quận 1: Tổng quãng đường=23.05km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.81 (phục vụ) = 4.77h
#  Quận 0: Tổng quãng đường=21.96km, Thời gian di chuyển=0.44h
#  Quận 0: 0.44 (di chuyển) + 0.75 (nạp lại) + 3.55 (phục vụ) = 4.74h
#  Quận 1: Tổng quãng đường=22.64km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.80 (phục vụ) = 4.75h
#  Quận 0: Tổng quãng đường=23.17km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.84 (phục vụ) = 5.05h
#  Quận 1: Tổng quãng đường=21.57km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.51 (phục vụ) = 4.44h
#  Quận 0: Tổng quãng đường=23.10km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.79 (phục vụ) = 5.00h
#  Quận 1: Tổng quãng đường=21.73km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.56 (phục vụ) = 4.49h
#  Quận 0: Tổng quãng đường=19.81km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.39h
#  Quận 1: Tổng quãng đường=23.21km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.86 (phục vụ) = 4.82h
#  Quận 0: Tổng quãng đường=21.59km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.51 (phục vụ) = 4.69h
#  Quận 1: Tổng quãng đường=22.78km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.84 (phục vụ) = 4.80h
#  Quận 0: Tổng quãng đường=19.93km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.40 (phục vụ) = 4.30h
#  Quận 1: Tổng quãng đường=24.89km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.95 (phục vụ) = 5.20h
#  Quận 0: Tổng quãng đường=22.70km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.68 (phục vụ) = 4.88h
#  Quận 1: Tổng quãng đường=21.47km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.67 (phục vụ) = 4.60h
#  Quận 0: Tổng quãng đường=19.90km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.37 (phục vụ) = 4.27h
#  Quận 1: Tổng quãng đường=24.06km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.98 (phục vụ) = 4.96h
#  Quận 0: Tổng quãng đường=23.02km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.65 (phục vụ) = 4.86h
#  Quận 1: Tổng quãng đường=21.52km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.70 (phục vụ) = 4.63h
#  Quận 0: Tổng quãng đường=22.07km, Thời gian di chuyển=0.44h
#  Quận 0: 0.44 (di chuyển) + 0.75 (nạp lại) + 3.69 (phục vụ) = 4.88h
#  Quận 1: Tổng quãng đường=22.13km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.66 (phục vụ) = 4.60h
#  Quận 0: Tổng quãng đường=19.48km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.39 (phục vụ) = 4.28h
#  Quận 1: Tổng quãng đường=25.04km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.96 (phục vụ) = 5.21h
#  Quận 0: Tổng quãng đường=19.08km, Thời gian di chuyển=0.38h
#  Quận 0: 0.38 (di chuyển) + 0.50 (nạp lại) + 3.33 (phục vụ) = 4.21h
#  Quận 1: Tổng quãng đường=24.95km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 4.02 (phục vụ) = 5.27h
#  Quận 0: Tổng quãng đường=19.51km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.33 (phục vụ) = 4.22h
#  Quận 1: Tổng quãng đường=25.17km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 4.02 (phục vụ) = 5.27h
#  Quận 0: Tổng quãng đường=19.61km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.38 (phục vụ) = 4.27h
#  Quận 1: Tổng quãng đường=24.83km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.97 (phục vụ) = 5.22h
#  Quận 0: Tổng quãng đường=19.80km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.39 (phục vụ) = 4.29h
#  Quận 1: Tổng quãng đường=23.50km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.96 (phục vụ) = 4.93h
#  Quận 0: Tổng quãng đường=22.50km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.68 (phục vụ) = 4.88h
#  Quận 1: Tổng quãng đường=22.44km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.67 (phục vụ) = 4.62h
#  Quận 0: Tổng quãng đường=22.44km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.63 (phục vụ) = 4.83h
#  Quận 1: Tổng quãng đường=22.64km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.72 (phục vụ) = 4.67h
#  Quận 0: Tổng quãng đường=19.04km, Thời gian di chuyển=0.38h
#  Quận 0: 0.38 (di chuyển) + 0.50 (nạp lại) + 3.33 (phục vụ) = 4.21h
#  Quận 1: Tổng quãng đường=25.00km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 4.02 (phục vụ) = 5.27h
#  Quận 0: Tổng quãng đường=22.28km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.67 (phục vụ) = 4.87h
#  Quận 1: Tổng quãng đường=21.90km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.68 (phục vụ) = 4.62h
#  Quận 0: Tổng quãng đường=19.77km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.33 (phục vụ) = 4.23h
#  Quận 1: Tổng quãng đường=23.55km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 4.02 (phục vụ) = 4.99h
#  Quận 0: Tổng quãng đường=22.93km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.66 (phục vụ) = 4.87h
#  Quận 1: Tổng quãng đường=21.80km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.69 (phục vụ) = 4.63h
#  Quận 0: Tổng quãng đường=19.00km, Thời gian di chuyển=0.38h
#  Quận 0: 0.38 (di chuyển) + 0.50 (nạp lại) + 3.33 (phục vụ) = 4.21h
#  Quận 1: Tổng quãng đường=25.08km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 4.02 (phục vụ) = 5.27h
#  Quận 0: Tổng quãng đường=19.59km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.33 (phục vụ) = 4.22h
#  Quận 1: Tổng quãng đường=25.14km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 4.02 (phục vụ) = 5.27h
#  Quận 0: Tổng quãng đường=18.95km, Thời gian di chuyển=0.38h
#  Quận 0: 0.38 (di chuyển) + 0.50 (nạp lại) + 3.39 (phục vụ) = 4.27h
#  Quận 1: Tổng quãng đường=24.11km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.96 (phục vụ) = 4.94h
#  Quận 0: Tổng quãng đường=19.18km, Thời gian di chuyển=0.38h
#  Quận 0: 0.38 (di chuyển) + 0.50 (nạp lại) + 3.40 (phục vụ) = 4.28h
#  Quận 1: Tổng quãng đường=24.75km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.95 (phục vụ) = 5.19h
#  Quận 0: Tổng quãng đường=19.39km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.36 (phục vụ) = 4.25h
#  Quận 1: Tổng quãng đường=24.74km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.99 (phục vụ) = 5.23h
#  Quận 0: Tổng quãng đường=22.45km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.62 (phục vụ) = 4.82h
#  Quận 1: Tổng quãng đường=21.95km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.73 (phục vụ) = 4.67h
#  Quận 0: Tổng quãng đường=22.97km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.63 (phục vụ) = 4.84h
#  Quận 1: Tổng quãng đường=21.32km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.72 (phục vụ) = 4.65h
#  Quận 0: Tổng quãng đường=22.36km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.62 (phục vụ) = 4.82h
#  Quận 1: Tổng quãng đường=21.35km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.73 (phục vụ) = 4.66h
#  Quận 0: Tổng quãng đường=20.72km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.51 (phục vụ) = 4.42h
#  Quận 1: Tổng quãng đường=23.55km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.84 (phục vụ) = 5.06h
#  Quận 0: Tổng quãng đường=23.44km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.79 (phục vụ) = 5.01h
#  Quận 1: Tổng quãng đường=20.03km, Thời gian di chuyển=0.40h
#  Quận 1: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.56 (phục vụ) = 4.46h
#  Quận 0: Tổng quãng đường=22.09km, Thời gian di chuyển=0.44h
#  Quận 0: 0.44 (di chuyển) + 0.75 (nạp lại) + 3.48 (phục vụ) = 4.67h
#  Quận 1: Tổng quãng đường=22.63km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.82h
#  Quận 0: Tổng quãng đường=23.84km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.76 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=20.10km, Thời gian di chuyển=0.40h
#  Quận 1: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.49h
#  Quận 0: Tổng quãng đường=22.84km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.80 (phục vụ) = 5.01h
#  Quận 1: Tổng quãng đường=20.68km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.46h
#  Quận 0: Tổng quãng đường=20.27km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.41h
#  Quận 1: Tổng quãng đường=23.69km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.85 (phục vụ) = 5.07h
#  Quận 0: Tổng quãng đường=19.86km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.34h
#  Quận 1: Tổng quãng đường=23.60km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.91 (phục vụ) = 5.13h
#  Quận 0: Tổng quãng đường=20.31km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.35h
#  Quận 1: Tổng quãng đường=23.82km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.91 (phục vụ) = 5.14h
#  Quận 0: Tổng quãng đường=20.39km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=23.49km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.86 (phục vụ) = 5.08h
#  Quận 0: Tổng quãng đường=22.00km, Thời gian di chuyển=0.44h
#  Quận 0: 0.44 (di chuyển) + 0.75 (nạp lại) + 3.50 (phục vụ) = 4.69h
#  Quận 1: Tổng quãng đường=22.09km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.85 (phục vụ) = 4.79h
#  Quận 0: Tổng quãng đường=23.28km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.79 (phục vụ) = 5.01h
#  Quận 1: Tổng quãng đường=20.98km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.56 (phục vụ) = 4.48h
#  Quận 0: Tổng quãng đường=23.24km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.74 (phục vụ) = 4.95h
#  Quận 1: Tổng quãng đường=21.18km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.53h
#  Quận 0: Tổng quãng đường=19.75km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=23.66km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.91 (phục vụ) = 5.13h
#  Quận 0: Tổng quãng đường=23.09km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=20.48km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.48h
#  Quận 0: Tổng quãng đường=20.50km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.35h
#  Quận 1: Tổng quãng đường=22.14km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.91 (phục vụ) = 4.85h
#  Quận 0: Tổng quãng đường=23.70km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=20.37km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.49h
#  Quận 0: Tổng quãng đường=19.71km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=22.73km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.91 (phục vụ) = 4.86h
#  Quận 0: Tổng quãng đường=20.39km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.35h
#  Quận 1: Tổng quãng đường=22.82km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.91 (phục vụ) = 4.87h
#  Quận 0: Tổng quãng đường=19.74km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.39h
#  Quận 1: Tổng quãng đường=22.66km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.85 (phục vụ) = 4.80h
#  Quận 0: Tổng quãng đường=19.95km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.51 (phục vụ) = 4.41h
#  Quận 1: Tổng quãng đường=22.36km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.84 (phục vụ) = 4.79h
#  Quận 0: Tổng quãng đường=20.10km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.37h
#  Quận 1: Tổng quãng đường=22.39km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.88 (phục vụ) = 4.83h
#  Quận 0: Tổng quãng đường=23.21km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.73 (phục vụ) = 4.94h
#  Quận 1: Tổng quãng đường=20.50km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.62 (phục vụ) = 4.53h
#  Quận 0: Tổng quãng đường=23.72km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.74 (phục vụ) = 4.96h
#  Quận 1: Tổng quãng đường=19.89km, Thời gian di chuyển=0.40h
#  Quận 1: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.51h
#  Quận 0: Tổng quãng đường=21.59km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.51 (phục vụ) = 4.69h
#  Quận 1: Tổng quãng đường=22.78km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.84 (phục vụ) = 4.80h
#  Quận 0: Tổng quãng đường=20.10km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=23.41km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.85 (phục vụ) = 5.07h
#  Quận 0: Tổng quãng đường=20.29km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.35h
#  Quận 1: Tổng quãng đường=23.87km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.91 (phục vụ) = 5.14h
#  Quận 0: Tổng quãng đường=22.99km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.79 (phục vụ) = 5.00h
#  Quận 1: Tổng quãng đường=20.90km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.56 (phục vụ) = 4.48h
#  Quận 0: Tổng quãng đường=22.99km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.74 (phục vụ) = 4.95h
#  Quận 1: Tổng quãng đường=20.27km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.52h
#  Quận 0: Tổng quãng đường=20.16km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.37h
#  Quận 1: Tổng quãng đường=23.73km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.10h
#  Quận 0: Tổng quãng đường=22.36km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.62 (phục vụ) = 4.82h
#  Quận 1: Tổng quãng đường=21.35km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.73 (phục vụ) = 4.66h
#
# Kết quả Local Search:
#  → Điểm tốt nhất: 0.0833
#  → Cải thiện: 9.5%
#
# Trực quan hóa Local Search...
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13540\4021880790.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('nipy_spectral', NUM_DISTRICTS)

# %%
print_strategic_plan(ls_solution, areas, ls_assignments, "LOCAL SEARCH")
# Out:
# ================================================================================
#  KẾ HOẠCH CHIẾN THUẬT - Thuật toán: LOCAL SEARCH
# ================================================================================
#  Quận 0: Tổng quãng đường=22.36km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.62 (phục vụ) = 4.82h
#  Quận 1: Tổng quãng đường=21.35km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.73 (phục vụ) = 4.66h
#
# ================================================================================================================================================================
# BẢNG TỔNG QUAN PHÂN CÔNG
# ================================================================================================================================================================
# Quận   Tài xế           Loại                 Xe               Khu vực    Tổng TG/Time     Bưu kiện/h     Trọng lượng        Chuyến   Tỷ lệ sử dụng
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# 0      2                Full-time            Xe máy to        24         4.82/8.0h        70.4 pcs/h     60.8/20 kg         4x       60.2%
# 1      1                Full-time            Xe máy to        26         4.66/8.0h        78.6 pcs/h     57.3/20 kg         3x       58.2%
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# TỔNG CỘNG                                          Workload: 7.35h  |  Bưu kiện/h: 74.4  |  Trọng lượng: 118.1kg  |  Tổng TG: 9.47h
# ================================================================================================================================================================

# %%
# =============================================================================
# BƯỚC 3: CHẠY VNS
# =============================================================================

print("\n" + "="*80)
print("THUẬT TOÁN 2: VNS (Variable Neighborhood Search)")
print("="*80)

vns_solution, vns_score = vns(initial_solution, areas)

print(f"\nKết quả VNS:")
print(f" → Điểm cuối: {vns_score:.4f}")
print(f" → Cải thiện: {((initial_score - vns_score) / initial_score * 100):.1f}%")

vns_assignments, vns_stats = assign_resources_to_districts(vns_solution, areas)

print("\nTrực quan hóa VNS...")
plot_solution(vns_solution, areas, 
             f"VNS - Score: {vns_score:.4f}")
# Out:
# ================================================================================
# THUẬT TOÁN 2: VNS (Variable Neighborhood Search)
# ================================================================================
#  Quận 0: Tổng quãng đường=24.53km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.86 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=20.07km, Thời gian di chuyển=0.40h
#  Quận 1: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.39h
#  Quận 0: Tổng quãng đường=10.12km, Thời gian di chuyển=0.20h
#  Quận 0: 0.20 (di chuyển) + 0.25 (nạp lại) + 1.90 (phục vụ) = 2.35h
#  Quận 1: Tổng quãng đường=36.08km, Thời gian di chuyển=0.72h
#  Quận 1: 0.72 (di chuyển) + 1.00 (nạp lại) + 5.45 (phục vụ) = 7.17h
#  Quận 0: Tổng quãng đường=9.71km, Thời gian di chuyển=0.19h
#  Quận 0: 0.19 (di chuyển) + 0.25 (nạp lại) + 1.79 (phục vụ) = 2.23h
#  Quận 1: Tổng quãng đường=36.95km, Thời gian di chuyển=0.74h
#  Quận 1: 0.74 (di chuyển) + 1.00 (nạp lại) + 5.56 (phục vụ) = 7.30h
#  Quận 0: Tổng quãng đường=11.41km, Thời gian di chuyển=0.23h
#  Quận 0: 0.23 (di chuyển) + 0.25 (nạp lại) + 2.07 (phục vụ) = 2.55h
#  Quận 1: Tổng quãng đường=34.88km, Thời gian di chuyển=0.70h
#  Quận 1: 0.70 (di chuyển) + 1.00 (nạp lại) + 5.28 (phục vụ) = 6.98h
#  Quận 0: Tổng quãng đường=11.10km, Thời gian di chuyển=0.22h
#  Quận 0: 0.22 (di chuyển) + 0.25 (nạp lại) + 1.96 (phục vụ) = 2.43h
#  Quận 1: Tổng quãng đường=35.75km, Thời gian di chuyển=0.71h
#  Quận 1: 0.71 (di chuyển) + 1.00 (nạp lại) + 5.39 (phục vụ) = 7.10h
#  Quận 0: Tổng quãng đường=10.12km, Thời gian di chuyển=0.20h
#  Quận 0: 0.20 (di chuyển) + 0.25 (nạp lại) + 1.90 (phục vụ) = 2.35h
#  Quận 1: Tổng quãng đường=36.08km, Thời gian di chuyển=0.72h
#  Quận 1: 0.72 (di chuyển) + 1.00 (nạp lại) + 5.45 (phục vụ) = 7.17h
#  Quận 0: Tổng quãng đường=11.66km, Thời gian di chuyển=0.23h
#  Quận 0: 0.23 (di chuyển) + 0.25 (nạp lại) + 2.21 (phục vụ) = 2.69h
#  Quận 1: Tổng quãng đường=33.93km, Thời gian di chuyển=0.68h
#  Quận 1: 0.68 (di chuyển) + 1.00 (nạp lại) + 5.14 (phục vụ) = 6.82h
#  Quận 0: Tổng quãng đường=11.39km, Thời gian di chuyển=0.23h
#  Quận 0: 0.23 (di chuyển) + 0.25 (nạp lại) + 2.10 (phục vụ) = 2.58h
#  Quận 1: Tổng quãng đường=34.82km, Thời gian di chuyển=0.70h
#  Quận 1: 0.70 (di chuyển) + 1.00 (nạp lại) + 5.25 (phục vụ) = 6.95h
#  Quận 0: Tổng quãng đường=10.44km, Thời gian di chuyển=0.21h
#  Quận 0: 0.21 (di chuyển) + 0.25 (nạp lại) + 2.04 (phục vụ) = 2.50h
#  Quận 1: Tổng quãng đường=35.13km, Thời gian di chuyển=0.70h
#  Quận 1: 0.70 (di chuyển) + 1.00 (nạp lại) + 5.31 (phục vụ) = 7.01h
#  Quận 0: Tổng quãng đường=11.41km, Thời gian di chuyển=0.23h
#  Quận 0: 0.23 (di chuyển) + 0.25 (nạp lại) + 2.07 (phục vụ) = 2.55h
#  Quận 1: Tổng quãng đường=34.88km, Thời gian di chuyển=0.70h
#  Quận 1: 0.70 (di chuyển) + 1.00 (nạp lại) + 5.28 (phục vụ) = 6.98h
#  Quận 0: Tổng quãng đường=13.25km, Thời gian di chuyển=0.26h
#  Quận 0: 0.26 (di chuyển) + 0.25 (nạp lại) + 2.35 (phục vụ) = 2.86h
#  Quận 1: Tổng quãng đường=32.21km, Thời gian di chuyển=0.64h
#  Quận 1: 0.64 (di chuyển) + 0.75 (nạp lại) + 5.00 (phục vụ) = 6.39h
#  Quận 0: Tổng quãng đường=12.89km, Thời gian di chuyển=0.26h
#  Quận 0: 0.26 (di chuyển) + 0.25 (nạp lại) + 2.24 (phục vụ) = 2.75h
#  Quận 1: Tổng quãng đường=33.61km, Thời gian di chuyển=0.67h
#  Quận 1: 0.67 (di chuyển) + 1.00 (nạp lại) + 5.11 (phục vụ) = 6.78h
#  Quận 0: Tổng quãng đường=11.95km, Thời gian di chuyển=0.24h
#  Quận 0: 0.24 (di chuyển) + 0.25 (nạp lại) + 2.18 (phục vụ) = 2.67h
#  Quận 1: Tổng quãng đường=33.93km, Thời gian di chuyển=0.68h
#  Quận 1: 0.68 (di chuyển) + 1.00 (nạp lại) + 5.17 (phục vụ) = 6.85h
#  Quận 0: Tổng quãng đường=12.90km, Thời gian di chuyển=0.26h
#  Quận 0: 0.26 (di chuyển) + 0.25 (nạp lại) + 2.21 (phục vụ) = 2.72h
#  Quận 1: Tổng quãng đường=33.22km, Thời gian di chuyển=0.66h
#  Quận 1: 0.66 (di chuyển) + 0.75 (nạp lại) + 5.14 (phục vụ) = 6.55h
#  Quận 0: Tổng quãng đường=11.66km, Thời gian di chuyển=0.23h
#  Quận 0: 0.23 (di chuyển) + 0.25 (nạp lại) + 2.21 (phục vụ) = 2.69h
#  Quận 1: Tổng quãng đường=33.93km, Thời gian di chuyển=0.68h
#  Quận 1: 0.68 (di chuyển) + 1.00 (nạp lại) + 5.14 (phục vụ) = 6.82h
#  Quận 0: Tổng quãng đường=13.89km, Thời gian di chuyển=0.28h
#  Quận 0: 0.28 (di chuyển) + 0.25 (nạp lại) + 2.53 (phục vụ) = 3.06h
#  Quận 1: Tổng quãng đường=31.81km, Thời gian di chuyển=0.64h
#  Quận 1: 0.64 (di chuyển) + 0.75 (nạp lại) + 4.82 (phục vụ) = 6.21h
#  Quận 0: Tổng quãng đường=13.54km, Thời gian di chuyển=0.27h
#  Quận 0: 0.27 (di chuyển) + 0.25 (nạp lại) + 2.42 (phục vụ) = 2.94h
#  Quận 1: Tổng quãng đường=33.25km, Thời gian di chuyển=0.67h
#  Quận 1: 0.67 (di chuyển) + 1.00 (nạp lại) + 4.93 (phục vụ) = 6.60h
#  Quận 0: Tổng quãng đường=12.64km, Thời gian di chuyển=0.25h
#  Quận 0: 0.25 (di chuyển) + 0.25 (nạp lại) + 2.36 (phục vụ) = 2.86h
#  Quận 1: Tổng quãng đường=33.56km, Thời gian di chuyển=0.67h
#  Quận 1: 0.67 (di chuyển) + 1.00 (nạp lại) + 4.99 (phục vụ) = 6.66h
#  Quận 0: Tổng quãng đường=13.54km, Thời gian di chuyển=0.27h
#  Quận 0: 0.27 (di chuyển) + 0.25 (nạp lại) + 2.39 (phục vụ) = 2.91h
#  Quận 1: Tổng quãng đường=32.85km, Thời gian di chuyển=0.66h
#  Quận 1: 0.66 (di chuyển) + 0.75 (nạp lại) + 4.96 (phục vụ) = 6.37h
#  Quận 0: Tổng quãng đường=12.29km, Thời gian di chuyển=0.25h
#  Quận 0: 0.25 (di chuyển) + 0.25 (nạp lại) + 2.39 (phục vụ) = 2.89h
#  Quận 1: Tổng quãng đường=33.53km, Thời gian di chuyển=0.67h
#  Quận 1: 0.67 (di chuyển) + 1.00 (nạp lại) + 4.96 (phục vụ) = 6.63h
#  Quận 0: Tổng quãng đường=13.25km, Thời gian di chuyển=0.26h
#  Quận 0: 0.26 (di chuyển) + 0.25 (nạp lại) + 2.35 (phục vụ) = 2.86h
#  Quận 1: Tổng quãng đường=32.21km, Thời gian di chuyển=0.64h
#  Quận 1: 0.64 (di chuyển) + 0.75 (nạp lại) + 5.00 (phục vụ) = 6.39h
#  Quận 0: Tổng quãng đường=16.03km, Thời gian di chuyển=0.32h
#  Quận 0: 0.32 (di chuyển) + 0.50 (nạp lại) + 2.65 (phục vụ) = 3.47h
#  Quận 1: Tổng quãng đường=30.63km, Thời gian di chuyển=0.61h
#  Quận 1: 0.61 (di chuyển) + 0.75 (nạp lại) + 4.70 (phục vụ) = 6.06h
#  Quận 0: Tổng quãng đường=15.73km, Thời gian di chuyển=0.31h
#  Quận 0: 0.31 (di chuyển) + 0.50 (nạp lại) + 2.54 (phục vụ) = 3.35h
#  Quận 1: Tổng quãng đường=31.63km, Thời gian di chuyển=0.63h
#  Quận 1: 0.63 (di chuyển) + 0.75 (nạp lại) + 4.81 (phục vụ) = 6.19h
#  Quận 0: Tổng quãng đường=14.93km, Thời gian di chuyển=0.30h
#  Quận 0: 0.30 (di chuyển) + 0.50 (nạp lại) + 2.48 (phục vụ) = 3.28h
#  Quận 1: Tổng quãng đường=31.87km, Thời gian di chuyển=0.64h
#  Quận 1: 0.64 (di chuyển) + 0.75 (nạp lại) + 4.87 (phục vụ) = 6.26h
#  Quận 0: Tổng quãng đường=15.71km, Thời gian di chuyển=0.31h
#  Quận 0: 0.31 (di chuyển) + 0.50 (nạp lại) + 2.51 (phục vụ) = 3.32h
#  Quận 1: Tổng quãng đường=31.70km, Thời gian di chuyển=0.63h
#  Quận 1: 0.63 (di chuyển) + 0.75 (nạp lại) + 4.84 (phục vụ) = 6.22h
#  Quận 0: Tổng quãng đường=14.47km, Thời gian di chuyển=0.29h
#  Quận 0: 0.29 (di chuyển) + 0.50 (nạp lại) + 2.51 (phục vụ) = 3.30h
#  Quận 1: Tổng quãng đường=31.86km, Thời gian di chuyển=0.64h
#  Quận 1: 0.64 (di chuyển) + 0.75 (nạp lại) + 4.84 (phục vụ) = 6.23h
#  Quận 0: Tổng quãng đường=15.49km, Thời gian di chuyển=0.31h
#  Quận 0: 0.31 (di chuyển) + 0.50 (nạp lại) + 2.47 (phục vụ) = 3.28h
#  Quận 1: Tổng quãng đường=31.07km, Thời gian di chuyển=0.62h
#  Quận 1: 0.62 (di chuyển) + 0.75 (nạp lại) + 4.88 (phục vụ) = 6.25h
#  Quận 0: Tổng quãng đường=13.89km, Thời gian di chuyển=0.28h
#  Quận 0: 0.28 (di chuyển) + 0.25 (nạp lại) + 2.53 (phục vụ) = 3.06h
#  Quận 1: Tổng quãng đường=31.81km, Thời gian di chuyển=0.64h
#  Quận 1: 0.64 (di chuyển) + 0.75 (nạp lại) + 4.82 (phục vụ) = 6.21h
#  Quận 0: Tổng quãng đường=16.96km, Thời gian di chuyển=0.34h
#  Quận 0: 0.34 (di chuyển) + 0.50 (nạp lại) + 2.79 (phục vụ) = 3.63h
#  Quận 1: Tổng quãng đường=30.00km, Thời gian di chuyển=0.60h
#  Quận 1: 0.60 (di chuyển) + 0.75 (nạp lại) + 4.56 (phục vụ) = 5.91h
#  Quận 0: Tổng quãng đường=16.60km, Thời gian di chuyển=0.33h
#  Quận 0: 0.33 (di chuyển) + 0.50 (nạp lại) + 2.68 (phục vụ) = 3.51h
#  Quận 1: Tổng quãng đường=31.00km, Thời gian di chuyển=0.62h
#  Quận 1: 0.62 (di chuyển) + 0.75 (nạp lại) + 4.67 (phục vụ) = 6.04h
#  Quận 0: Tổng quãng đường=15.82km, Thời gian di chuyển=0.32h
#  Quận 0: 0.32 (di chuyển) + 0.50 (nạp lại) + 2.62 (phục vụ) = 3.44h
#  Quận 1: Tổng quãng đường=31.23km, Thời gian di chuyển=0.62h
#  Quận 1: 0.62 (di chuyển) + 0.75 (nạp lại) + 4.73 (phục vụ) = 6.10h
#  Quận 0: Tổng quãng đường=16.57km, Thời gian di chuyển=0.33h
#  Quận 0: 0.33 (di chuyển) + 0.50 (nạp lại) + 2.65 (phục vụ) = 3.48h
#  Quận 1: Tổng quãng đường=31.07km, Thời gian di chuyển=0.62h
#  Quận 1: 0.62 (di chuyển) + 0.75 (nạp lại) + 4.70 (phục vụ) = 6.07h
#  Quận 0: Tổng quãng đường=15.45km, Thời gian di chuyển=0.31h
#  Quận 0: 0.31 (di chuyển) + 0.50 (nạp lại) + 2.65 (phục vụ) = 3.46h
#  Quận 1: Tổng quãng đường=31.24km, Thời gian di chuyển=0.62h
#  Quận 1: 0.62 (di chuyển) + 0.75 (nạp lại) + 4.70 (phục vụ) = 6.07h
#  Quận 0: Tổng quãng đường=16.42km, Thời gian di chuyển=0.33h
#  Quận 0: 0.33 (di chuyển) + 0.50 (nạp lại) + 2.61 (phục vụ) = 3.44h
#  Quận 1: Tổng quãng đường=30.43km, Thời gian di chuyển=0.61h
#  Quận 1: 0.61 (di chuyển) + 0.75 (nạp lại) + 4.74 (phục vụ) = 6.10h
#  Quận 0: Tổng quãng đường=16.19km, Thời gian di chuyển=0.32h
#  Quận 0: 0.32 (di chuyển) + 0.50 (nạp lại) + 2.67 (phục vụ) = 3.49h
#  Quận 1: Tổng quãng đường=31.17km, Thời gian di chuyển=0.62h
#  Quận 1: 0.62 (di chuyển) + 0.75 (nạp lại) + 4.68 (phục vụ) = 6.05h
#  Quận 0: Tổng quãng đường=16.03km, Thời gian di chuyển=0.32h
#  Quận 0: 0.32 (di chuyển) + 0.50 (nạp lại) + 2.65 (phục vụ) = 3.47h
#  Quận 1: Tổng quãng đường=30.63km, Thời gian di chuyển=0.61h
#  Quận 1: 0.61 (di chuyển) + 0.75 (nạp lại) + 4.70 (phục vụ) = 6.06h
#  Quận 0: Tổng quãng đường=18.01km, Thời gian di chuyển=0.36h
#  Quận 0: 0.36 (di chuyển) + 0.50 (nạp lại) + 2.97 (phục vụ) = 3.83h
#  Quận 1: Tổng quãng đường=28.87km, Thời gian di chuyển=0.58h
#  Quận 1: 0.58 (di chuyển) + 0.75 (nạp lại) + 4.38 (phục vụ) = 5.71h
#  Quận 0: Tổng quãng đường=17.68km, Thời gian di chuyển=0.35h
#  Quận 0: 0.35 (di chuyển) + 0.50 (nạp lại) + 2.86 (phục vụ) = 3.71h
#  Quận 1: Tổng quãng đường=29.88km, Thời gian di chuyển=0.60h
#  Quận 1: 0.60 (di chuyển) + 0.75 (nạp lại) + 4.49 (phục vụ) = 5.84h
#  Quận 0: Tổng quãng đường=16.90km, Thời gian di chuyển=0.34h
#  Quận 0: 0.34 (di chuyển) + 0.50 (nạp lại) + 2.80 (phục vụ) = 3.64h
#  Quận 1: Tổng quãng đường=30.11km, Thời gian di chuyển=0.60h
#  Quận 1: 0.60 (di chuyển) + 0.75 (nạp lại) + 4.55 (phục vụ) = 5.90h
#  Quận 0: Tổng quãng đường=17.64km, Thời gian di chuyển=0.35h
#  Quận 0: 0.35 (di chuyển) + 0.50 (nạp lại) + 2.83 (phục vụ) = 3.68h
#  Quận 1: Tổng quãng đường=29.95km, Thời gian di chuyển=0.60h
#  Quận 1: 0.60 (di chuyển) + 0.75 (nạp lại) + 4.52 (phục vụ) = 5.87h
#  Quận 0: Tổng quãng đường=16.47km, Thời gian di chuyển=0.33h
#  Quận 0: 0.33 (di chuyển) + 0.50 (nạp lại) + 2.83 (phục vụ) = 3.66h
#  Quận 1: Tổng quãng đường=30.10km, Thời gian di chuyển=0.60h
#  Quận 1: 0.60 (di chuyển) + 0.75 (nạp lại) + 4.52 (phục vụ) = 5.87h
#  Quận 0: Tổng quãng đường=17.51km, Thời gian di chuyển=0.35h
#  Quận 0: 0.35 (di chuyển) + 0.50 (nạp lại) + 2.79 (phục vụ) = 3.64h
#  Quận 1: Tổng quãng đường=29.32km, Thời gian di chuyển=0.59h
#  Quận 1: 0.59 (di chuyển) + 0.75 (nạp lại) + 4.56 (phục vụ) = 5.90h
#  Quận 0: Tổng quãng đường=17.28km, Thời gian di chuyển=0.35h
#  Quận 0: 0.35 (di chuyển) + 0.50 (nạp lại) + 2.85 (phục vụ) = 3.70h
#  Quận 1: Tổng quãng đường=30.05km, Thời gian di chuyển=0.60h
#  Quận 1: 0.60 (di chuyển) + 0.75 (nạp lại) + 4.50 (phục vụ) = 5.85h
#  Quận 0: Tổng quãng đường=17.06km, Thời gian di chuyển=0.34h
#  Quận 0: 0.34 (di chuyển) + 0.50 (nạp lại) + 2.83 (phục vụ) = 3.67h
#  Quận 1: Tổng quãng đường=29.49km, Thời gian di chuyển=0.59h
#  Quận 1: 0.59 (di chuyển) + 0.75 (nạp lại) + 4.52 (phục vụ) = 5.86h
#  Quận 0: Tổng quãng đường=16.96km, Thời gian di chuyển=0.34h
#  Quận 0: 0.34 (di chuyển) + 0.50 (nạp lại) + 2.79 (phục vụ) = 3.63h
#  Quận 1: Tổng quãng đường=30.00km, Thời gian di chuyển=0.60h
#  Quận 1: 0.60 (di chuyển) + 0.75 (nạp lại) + 4.56 (phục vụ) = 5.91h
#  Quận 0: Tổng quãng đường=16.61km, Thời gian di chuyển=0.33h
#  Quận 0: 0.33 (di chuyển) + 0.50 (nạp lại) + 2.81 (phục vụ) = 3.64h
#  Quận 1: Tổng quãng đường=30.32km, Thời gian di chuyển=0.61h
#  Quận 1: 0.61 (di chuyển) + 0.75 (nạp lại) + 4.54 (phục vụ) = 5.90h
#  Quận 0: Tổng quãng đường=17.28km, Thời gian di chuyển=0.35h
#  Quận 0: 0.35 (di chuyển) + 0.50 (nạp lại) + 2.79 (phục vụ) = 3.64h
#  Quận 1: Tổng quãng đường=30.18km, Thời gian di chuyển=0.60h
#  Quận 1: 0.60 (di chuyển) + 0.75 (nạp lại) + 4.56 (phục vụ) = 5.91h
#  Quận 0: Tổng quãng đường=17.43km, Thời gian di chuyển=0.35h
#  Quận 0: 0.35 (di chuyển) + 0.50 (nạp lại) + 2.84 (phục vụ) = 3.69h
#  Quận 1: Tổng quãng đường=29.83km, Thời gian di chuyển=0.60h
#  Quận 1: 0.60 (di chuyển) + 0.75 (nạp lại) + 4.51 (phục vụ) = 5.86h
#  Quận 0: Tổng quãng đường=19.48km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.08 (phục vụ) = 3.97h
#  Quận 1: Tổng quãng đường=27.95km, Thời gian di chuyển=0.56h
#  Quận 1: 0.56 (di chuyển) + 0.75 (nạp lại) + 4.27 (phục vụ) = 5.58h
#  Quận 0: Tổng quãng đường=19.08km, Thời gian di chuyển=0.38h
#  Quận 0: 0.38 (di chuyển) + 0.50 (nạp lại) + 2.97 (phục vụ) = 3.85h
#  Quận 1: Tổng quãng đường=28.94km, Thời gian di chuyển=0.58h
#  Quận 1: 0.58 (di chuyển) + 0.75 (nạp lại) + 4.38 (phục vụ) = 5.71h
#  Quận 0: Tổng quãng đường=18.35km, Thời gian di chuyển=0.37h
#  Quận 0: 0.37 (di chuyển) + 0.50 (nạp lại) + 2.91 (phục vụ) = 3.78h
#  Quận 1: Tổng quãng đường=29.18km, Thời gian di chuyển=0.58h
#  Quận 1: 0.58 (di chuyển) + 0.75 (nạp lại) + 4.44 (phục vụ) = 5.77h
#  Quận 0: Tổng quãng đường=19.03km, Thời gian di chuyển=0.38h
#  Quận 0: 0.38 (di chuyển) + 0.50 (nạp lại) + 2.94 (phục vụ) = 3.82h
#  Quận 1: Tổng quãng đường=29.01km, Thời gian di chuyển=0.58h
#  Quận 1: 0.58 (di chuyển) + 0.75 (nạp lại) + 4.41 (phục vụ) = 5.74h
#  Quận 0: Tổng quãng đường=21.00km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.24 (phục vụ) = 4.16h
#  Quận 1: Tổng quãng đường=26.98km, Thời gian di chuyển=0.54h
#  Quận 1: 0.54 (di chuyển) + 0.75 (nạp lại) + 4.11 (phục vụ) = 5.40h
#  Quận 0: Tổng quãng đường=20.53km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.13 (phục vụ) = 4.04h
#  Quận 1: Tổng quãng đường=27.93km, Thời gian di chuyển=0.56h
#  Quận 1: 0.56 (di chuyển) + 0.75 (nạp lại) + 4.22 (phục vụ) = 5.53h
#  Quận 0: Tổng quãng đường=19.86km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.07 (phục vụ) = 3.97h
#  Quận 1: Tổng quãng đường=28.20km, Thời gian di chuyển=0.56h
#  Quận 1: 0.56 (di chuyển) + 0.75 (nạp lại) + 4.28 (phục vụ) = 5.59h
#  Quận 0: Tổng quãng đường=20.47km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.10 (phục vụ) = 4.01h
#  Quận 1: Tổng quãng đường=28.00km, Thời gian di chuyển=0.56h
#  Quận 1: 0.56 (di chuyển) + 0.75 (nạp lại) + 4.25 (phục vụ) = 5.56h
#  Quận 0: Tổng quãng đường=19.48km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.08 (phục vụ) = 3.97h
#  Quận 1: Tổng quãng đường=27.95km, Thời gian di chuyển=0.56h
#  Quận 1: 0.56 (di chuyển) + 0.75 (nạp lại) + 4.27 (phục vụ) = 5.58h
#  Quận 0: Tổng quãng đường=19.54km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.10 (phục vụ) = 3.99h
#  Quận 1: Tổng quãng đường=28.21km, Thời gian di chuyển=0.56h
#  Quận 1: 0.56 (di chuyển) + 0.75 (nạp lại) + 4.25 (phục vụ) = 5.56h
#  Quận 0: Tổng quãng đường=20.57km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.06 (phục vụ) = 3.97h
#  Quận 1: Tổng quãng đường=27.38km, Thời gian di chuyển=0.55h
#  Quận 1: 0.55 (di chuyển) + 0.75 (nạp lại) + 4.29 (phục vụ) = 5.59h
#  Quận 0: Tổng quãng đường=20.18km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.12 (phục vụ) = 4.02h
#  Quận 1: Tổng quãng đường=28.11km, Thời gian di chuyển=0.56h
#  Quận 1: 0.56 (di chuyển) + 0.75 (nạp lại) + 4.23 (phục vụ) = 5.54h
#  Quận 0: Tổng quãng đường=19.92km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.06 (phục vụ) = 3.96h
#  Quận 1: Tổng quãng đường=28.10km, Thời gian di chuyển=0.56h
#  Quận 1: 0.56 (di chuyển) + 0.75 (nạp lại) + 4.29 (phục vụ) = 5.60h
#  Quận 0: Tổng quãng đường=22.25km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.35 (phục vụ) = 4.30h
#  Quận 1: Tổng quãng đường=26.21km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 4.00 (phục vụ) = 5.27h
#  Quận 0: Tổng quãng đường=21.72km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.24 (phục vụ) = 4.17h
#  Quận 1: Tổng quãng đường=27.12km, Thời gian di chuyển=0.54h
#  Quận 1: 0.54 (di chuyển) + 0.75 (nạp lại) + 4.11 (phục vụ) = 5.40h
#  Quận 0: Tổng quãng đường=21.11km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.18 (phục vụ) = 4.10h
#  Quận 1: Tổng quãng đường=27.43km, Thời gian di chuyển=0.55h
#  Quận 1: 0.55 (di chuyển) + 0.75 (nạp lại) + 4.17 (phục vụ) = 5.47h
#  Quận 0: Tổng quãng đường=21.66km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.21 (phục vụ) = 4.14h
#  Quận 1: Tổng quãng đường=27.19km, Thời gian di chuyển=0.54h
#  Quận 1: 0.54 (di chuyển) + 0.75 (nạp lại) + 4.14 (phục vụ) = 5.43h
#  Quận 0: Tổng quãng đường=20.79km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.19 (phục vụ) = 4.11h
#  Quận 1: Tổng quãng đường=27.22km, Thời gian di chuyển=0.54h
#  Quận 1: 0.54 (di chuyển) + 0.75 (nạp lại) + 4.16 (phục vụ) = 5.45h
#  Quận 0: Tổng quãng đường=20.83km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.21 (phục vụ) = 4.13h
#  Quận 1: Tổng quãng đường=27.43km, Thời gian di chuyển=0.55h
#  Quận 1: 0.55 (di chuyển) + 0.75 (nạp lại) + 4.14 (phục vụ) = 5.44h
#  Quận 0: Tổng quãng đường=21.86km, Thời gian di chuyển=0.44h
#  Quận 0: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.17 (phục vụ) = 4.11h
#  Quận 1: Tổng quãng đường=26.58km, Thời gian di chuyển=0.53h
#  Quận 1: 0.53 (di chuyển) + 0.75 (nạp lại) + 4.18 (phục vụ) = 5.46h
#  Quận 0: Tổng quãng đường=21.41km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.23 (phục vụ) = 4.16h
#  Quận 1: Tổng quãng đường=27.32km, Thời gian di chuyển=0.55h
#  Quận 1: 0.55 (di chuyển) + 0.75 (nạp lại) + 4.12 (phục vụ) = 5.42h
#  Quận 0: Tổng quãng đường=21.18km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.17 (phục vụ) = 4.09h
#  Quận 1: Tổng quãng đường=27.32km, Thời gian di chuyển=0.55h
#  Quận 1: 0.55 (di chuyển) + 0.75 (nạp lại) + 4.18 (phục vụ) = 5.48h
#  Quận 0: Tổng quãng đường=21.00km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.24 (phục vụ) = 4.16h
#  Quận 1: Tổng quãng đường=26.98km, Thời gian di chuyển=0.54h
#  Quận 1: 0.54 (di chuyển) + 0.75 (nạp lại) + 4.11 (phục vụ) = 5.40h
#  Quận 0: Tổng quãng đường=20.87km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.19 (phục vụ) = 4.11h
#  Quận 1: Tổng quãng đường=27.56km, Thời gian di chuyển=0.55h
#  Quận 1: 0.55 (di chuyển) + 0.75 (nạp lại) + 4.16 (phục vụ) = 5.46h
#  Quận 0: Tổng quãng đường=21.35km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.17 (phục vụ) = 4.10h
#  Quận 1: Tổng quãng đường=27.43km, Thời gian di chuyển=0.55h
#  Quận 1: 0.55 (di chuyển) + 0.75 (nạp lại) + 4.18 (phục vụ) = 5.48h
#  Quận 0: Tổng quãng đường=21.59km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.22 (phục vụ) = 4.15h
#  Quận 1: Tổng quãng đường=27.10km, Thời gian di chuyển=0.54h
#  Quận 1: 0.54 (di chuyển) + 0.75 (nạp lại) + 4.13 (phục vụ) = 5.42h
#  Quận 0: Tổng quãng đường=23.71km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.46h
#  Quận 1: Tổng quãng đường=25.10km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.86 (phục vụ) = 5.11h
#  Quận 0: Tổng quãng đường=23.12km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.38 (phục vụ) = 4.34h
#  Quận 1: Tổng quãng đường=25.98km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.97 (phục vụ) = 5.24h
#  Quận 0: Tổng quãng đường=22.58km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.32 (phục vụ) = 4.27h
#  Quận 1: Tổng quãng đường=26.32km, Thời gian di chuyển=0.53h
#  Quận 1: 0.53 (di chuyển) + 0.75 (nạp lại) + 4.03 (phục vụ) = 5.31h
#  Quận 0: Tổng quãng đường=23.06km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.35 (phục vụ) = 4.31h
#  Quận 1: Tổng quãng đường=26.05km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 4.00 (phục vụ) = 5.27h
#  Quận 0: Tổng quãng đường=22.31km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.33 (phục vụ) = 4.28h
#  Quận 1: Tổng quãng đường=26.14km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 4.02 (phục vụ) = 5.29h
#  Quận 0: Tổng quãng đường=22.32km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.35 (phục vụ) = 4.30h
#  Quận 1: Tổng quãng đường=26.29km, Thời gian di chuyển=0.53h
#  Quận 1: 0.53 (di chuyển) + 0.75 (nạp lại) + 4.00 (phục vụ) = 5.28h
#  Quận 0: Tổng quãng đường=23.35km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.31 (phục vụ) = 4.28h
#  Quận 1: Tổng quãng đường=25.44km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 4.04 (phục vụ) = 5.30h
#  Quận 0: Tổng quãng đường=22.83km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.37 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=26.19km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.98 (phục vụ) = 5.25h
#  Quận 0: Tổng quãng đường=22.65km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.31 (phục vụ) = 4.26h
#  Quận 1: Tổng quãng đường=26.21km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 4.04 (phục vụ) = 5.31h
#  Quận 0: Tổng quãng đường=22.52km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.38 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=25.91km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.97 (phục vụ) = 5.24h
#  Quận 0: Tổng quãng đường=22.32km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.33 (phục vụ) = 4.28h
#  Quận 1: Tổng quãng đường=26.40km, Thời gian di chuyển=0.53h
#  Quận 1: 0.53 (di chuyển) + 0.75 (nạp lại) + 4.02 (phục vụ) = 5.30h
#  Quận 0: Tổng quãng đường=22.76km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.31 (phục vụ) = 4.27h
#  Quận 1: Tổng quãng đường=26.30km, Thời gian di chuyển=0.53h
#  Quận 1: 0.53 (di chuyển) + 0.75 (nạp lại) + 4.04 (phục vụ) = 5.32h
#  Quận 0: Tổng quãng đường=23.02km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.36 (phục vụ) = 4.32h
#  Quận 1: Tổng quãng đường=25.97km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.99 (phục vụ) = 5.26h
#  Quận 0: Tổng quãng đường=22.25km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.35 (phục vụ) = 4.30h
#  Quận 1: Tổng quãng đường=26.21km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 4.00 (phục vụ) = 5.27h
#  Quận 0: Tổng quãng đường=25.05km, Thời gian di chuyển=0.50h
#  Quận 0: 0.50 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.61h
#  Quận 1: Tổng quãng đường=23.63km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.74 (phục vụ) = 4.71h
#  Quận 0: Tổng quãng đường=24.41km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.49h
#  Quận 1: Tổng quãng đường=24.91km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.85 (phục vụ) = 5.10h
#  Quận 0: Tổng quãng đường=23.92km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.42h
#  Quận 1: Tổng quãng đường=25.28km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.91 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=24.34km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.46h
#  Quận 1: Tổng quãng đường=24.61km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.88 (phục vụ) = 4.87h
#  Quận 0: Tổng quãng đường=23.71km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.45 (phục vụ) = 4.42h
#  Quận 1: Tổng quãng đường=25.11km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.90 (phục vụ) = 5.15h
#  Quận 0: Tổng quãng đường=23.69km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.44h
#  Quận 1: Tổng quãng đường=25.20km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.13h
#  Quận 0: Tổng quãng đường=24.70km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.43 (phục vụ) = 4.42h
#  Quận 1: Tổng quãng đường=23.95km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.92 (phục vụ) = 4.90h
#  Quận 0: Tổng quãng đường=24.14km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.47h
#  Quận 1: Tổng quãng đường=25.14km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.86 (phục vụ) = 5.11h
#  Quận 0: Tổng quãng đường=23.99km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.43 (phục vụ) = 4.41h
#  Quận 1: Tổng quãng đường=25.16km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.92 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=23.91km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.48h
#  Quận 1: Tổng quãng đường=24.43km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.85 (phục vụ) = 4.84h
#  Quận 0: Tổng quãng đường=23.32km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.39 (phục vụ) = 4.36h
#  Quận 1: Tổng quãng đường=25.76km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.96 (phục vụ) = 5.23h
#  Quận 0: Tổng quãng đường=22.77km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.33 (phục vụ) = 4.29h
#  Quận 1: Tổng quãng đường=26.10km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 4.02 (phục vụ) = 5.29h
#  Quận 0: Tổng quãng đường=23.25km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.36 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=25.83km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.99 (phục vụ) = 5.26h
#  Quận 0: Tổng quãng đường=22.51km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.34 (phục vụ) = 4.29h
#  Quận 1: Tổng quãng đường=25.91km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 4.01 (phục vụ) = 5.28h
#  Quận 0: Tổng quãng đường=22.52km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.36 (phục vụ) = 4.31h
#  Quận 1: Tổng quãng đường=26.05km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.99 (phục vụ) = 5.26h
#  Quận 0: Tổng quãng đường=23.54km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.32 (phục vụ) = 4.29h
#  Quận 1: Tổng quãng đường=25.20km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 4.03 (phục vụ) = 5.28h
#  Quận 0: Tổng quãng đường=23.03km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.38 (phục vụ) = 4.34h
#  Quận 1: Tổng quãng đường=25.97km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.97 (phục vụ) = 5.24h
#  Quận 0: Tổng quãng đường=22.84km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.32 (phục vụ) = 4.28h
#  Quận 1: Tổng quãng đường=25.99km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 4.03 (phục vụ) = 5.30h
#  Quận 0: Tổng quãng đường=25.05km, Thời gian di chuyển=0.50h
#  Quận 0: 0.50 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.61h
#  Quận 1: Tổng quãng đường=23.63km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.74 (phục vụ) = 4.71h
#  Quận 0: Tổng quãng đường=22.53km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.34 (phục vụ) = 4.29h
#  Quận 1: Tổng quãng đường=26.16km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 4.01 (phục vụ) = 5.28h
#  Quận 0: Tổng quãng đường=22.96km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.32 (phục vụ) = 4.28h
#  Quận 1: Tổng quãng đường=26.09km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 4.03 (phục vụ) = 5.30h
#  Quận 0: Tổng quãng đường=23.22km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.37 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=25.74km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.98 (phục vụ) = 5.24h
#  Quận 0: Tổng quãng đường=22.45km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.36 (phục vụ) = 4.31h
#  Quận 1: Tổng quãng đường=25.98km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.99 (phục vụ) = 5.26h
#  Quận 0: Tổng quãng đường=22.52km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.38 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=25.91km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.97 (phục vụ) = 5.24h
#  Quận 0: Tổng quãng đường=26.23km, Thời gian di chuyển=0.52h
#  Quận 0: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.62 (phục vụ) = 4.89h
#  Quận 1: Tổng quãng đường=23.00km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.73 (phục vụ) = 4.69h
#  Quận 0: Tổng quãng đường=23.95km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.62 (phục vụ) = 4.60h
#  Quận 1: Tổng quãng đường=23.94km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.73 (phục vụ) = 4.71h
#  Quận 0: Tổng quãng đường=23.36km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.51 (phục vụ) = 4.48h
#  Quận 1: Tổng quãng đường=25.34km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.84 (phục vụ) = 5.10h
#  Quận 0: Tổng quãng đường=22.85km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.45 (phục vụ) = 4.41h
#  Quận 1: Tổng quãng đường=25.65km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.90 (phục vụ) = 5.16h
#  Quận 0: Tổng quãng đường=23.29km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.45h
#  Quận 1: Tổng quãng đường=24.99km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.87h
#  Quận 0: Tổng quãng đường=22.60km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.46 (phục vụ) = 4.41h
#  Quận 1: Tổng quãng đường=25.43km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.89 (phục vụ) = 5.15h
#  Quận 0: Tổng quãng đường=22.58km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.43h
#  Quận 1: Tổng quãng đường=25.61km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.87 (phục vụ) = 5.13h
#  Quận 0: Tổng quãng đường=23.60km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.41h
#  Quận 1: Tổng quãng đường=24.77km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.91 (phục vụ) = 5.16h
#  Quận 0: Tổng quãng đường=23.09km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.46h
#  Quận 1: Tổng quãng đường=25.54km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.85 (phục vụ) = 5.11h
#  Quận 0: Tổng quãng đường=22.92km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=25.54km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.91 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=25.70km, Thời gian di chuyển=0.51h
#  Quận 0: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.73 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=23.17km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.62 (phục vụ) = 4.58h
#  Quận 0: Tổng quãng đường=22.55km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.46 (phục vụ) = 4.41h
#  Quận 1: Tổng quãng đường=25.75km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.89 (phục vụ) = 5.15h
#  Quận 0: Tổng quãng đường=23.01km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=25.66km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.91 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=23.27km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.46h
#  Quận 1: Tổng quãng đường=25.31km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.86 (phục vụ) = 5.12h
#  Quận 0: Tổng quãng đường=22.54km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.43h
#  Quận 1: Tổng quãng đường=25.49km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.87 (phục vụ) = 5.13h
#  Quận 0: Tổng quãng đường=22.60km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.45h
#  Quận 1: Tổng quãng đường=25.43km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.85 (phục vụ) = 5.11h
#  Quận 0: Tổng quãng đường=26.29km, Thời gian di chuyển=0.53h
#  Quận 0: 0.53 (di chuyển) + 0.75 (nạp lại) + 3.74 (phục vụ) = 5.02h
#  Quận 1: Tổng quãng đường=22.55km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.56h
#  Quận 0: Tổng quãng đường=23.91km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.48h
#  Quận 1: Tổng quãng đường=24.43km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.85 (phục vụ) = 4.84h
#  Quận 0: Tổng quãng đường=25.81km, Thời gian di chuyển=0.52h
#  Quận 0: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.73 (phục vụ) = 5.00h
#  Quận 1: Tổng quãng đường=23.04km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.62 (phục vụ) = 4.58h
#  Quận 0: Tổng quãng đường=25.48km, Thời gian di chuyển=0.51h
#  Quận 0: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.74 (phục vụ) = 5.00h
#  Quận 1: Tổng quãng đường=23.41km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.58h
#  Quận 0: Tổng quãng đường=25.39km, Thời gian di chuyển=0.51h
#  Quận 0: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.75 (phục vụ) = 5.01h
#  Quận 1: Tổng quãng đường=23.51km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.60 (phục vụ) = 4.57h
#  Quận 0: Tổng quãng đường=25.30km, Thời gian di chuyển=0.51h
#  Quận 0: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.79 (phục vụ) = 5.05h
#  Quận 1: Tổng quãng đường=23.62km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.56 (phục vụ) = 4.53h
#  Quận 0: Tổng quãng đường=25.22km, Thời gian di chuyển=0.50h
#  Quận 0: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.74 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=23.72km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.58h
#  Quận 0: Tổng quãng đường=25.75km, Thời gian di chuyển=0.52h
#  Quận 0: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.80 (phục vụ) = 5.07h
#  Quận 1: Tổng quãng đường=22.76km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.51h
#  Quận 0: Tổng quãng đường=23.06km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=25.52km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.91 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=25.21km, Thời gian di chuyển=0.50h
#  Quận 0: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 5.03h
#  Quận 1: Tổng quãng đường=23.19km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.53h
#  Quận 0: Tổng quãng đường=25.32km, Thời gian di chuyển=0.51h
#  Quận 0: 0.51 (di chuyển) + 0.50 (nạp lại) + 3.79 (phục vụ) = 4.80h
#  Quận 1: Tổng quãng đường=22.90km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.56 (phục vụ) = 4.52h
#  Quận 0: Tổng quãng đường=24.77km, Thời gian di chuyển=0.50h
#  Quận 0: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.80 (phục vụ) = 5.05h
#  Quận 1: Tổng quãng đường=23.35km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.52h
#  Quận 0: Tổng quãng đường=22.78km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=25.56km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.91 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=23.05km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=25.63km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.91 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=25.86km, Thời gian di chuyển=0.52h
#  Quận 0: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.80 (phục vụ) = 5.07h
#  Quận 1: Tổng quãng đường=22.94km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.51h
#  Quận 0: Tổng quãng đường=23.17km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.46 (phục vụ) = 4.42h
#  Quận 1: Tổng quãng đường=25.46km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.89 (phục vụ) = 5.15h
#  Quận 0: Tổng quãng đường=25.78km, Thời gian di chuyển=0.52h
#  Quận 0: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.74 (phục vụ) = 5.01h
#  Quận 1: Tổng quãng đường=22.69km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.56h
#  Quận 0: Tổng quãng đường=25.90km, Thời gian di chuyển=0.52h
#  Quận 0: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.79 (phục vụ) = 5.06h
#  Quận 1: Tổng quãng đường=22.91km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.56 (phục vụ) = 4.52h
#  Quận 0: Tổng quãng đường=25.50km, Thời gian di chuyển=0.51h
#  Quận 0: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.73 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=23.03km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.62 (phục vụ) = 4.58h
#  Quận 0: Tổng quãng đường=23.25km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.44h
#  Quận 1: Tổng quãng đường=25.23km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.13h
#  Quận 0: Tổng quãng đường=25.83km, Thời gian di chuyển=0.52h
#  Quận 0: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.79 (phục vụ) = 5.06h
#  Quận 1: Tổng quãng đường=23.03km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.56 (phục vụ) = 4.52h
#  Quận 0: Tổng quãng đường=23.04km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.44h
#  Quận 1: Tổng quãng đường=25.62km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.87 (phục vụ) = 5.13h
#  Quận 0: Tổng quãng đường=24.71km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.73 (phục vụ) = 4.72h
#  Quận 1: Tổng quãng đường=23.25km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.62 (phục vụ) = 4.58h
#  Quận 0: Tổng quãng đường=25.30km, Thời gian di chuyển=0.51h
#  Quận 0: 0.51 (di chuyển) + 0.50 (nạp lại) + 3.74 (phục vụ) = 4.75h
#  Quận 1: Tổng quãng đường=22.51km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.56h
#  Quận 0: Tổng quãng đường=25.34km, Thời gian di chuyển=0.51h
#  Quận 0: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.74 (phục vụ) = 5.00h
#  Quận 1: Tổng quãng đường=23.03km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.57h
#  Quận 0: Tổng quãng đường=25.36km, Thời gian di chuyển=0.51h
#  Quận 0: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.79 (phục vụ) = 5.05h
#  Quận 1: Tổng quãng đường=23.59km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.56 (phục vụ) = 4.53h
#  Quận 0: Tổng quãng đường=22.97km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=25.71km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.91 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=24.97km, Thời gian di chuyển=0.50h
#  Quận 0: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.79 (phục vụ) = 5.04h
#  Quận 1: Tổng quãng đường=23.70km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.56 (phục vụ) = 4.53h
#  Quận 0: Tổng quãng đường=25.60km, Thời gian di chuyển=0.51h
#  Quận 0: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.79 (phục vụ) = 5.05h
#  Quận 1: Tổng quãng đường=22.62km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.56 (phục vụ) = 4.51h
#  Quận 0: Tổng quãng đường=23.02km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.43h
#  Quận 1: Tổng quãng đường=25.50km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.14h
#  Quận 0: Tổng quãng đường=23.95km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.62 (phục vụ) = 4.60h
#  Quận 1: Tổng quãng đường=23.94km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.73 (phục vụ) = 4.71h
#  Quận 0: Tổng quãng đường=32.62km, Thời gian di chuyển=0.65h
#  Quận 0: 0.65 (di chuyển) + 1.00 (nạp lại) + 4.80 (phục vụ) = 6.45h
#  Quận 1: Tổng quãng đường=15.74km, Thời gian di chuyển=0.31h
#  Quận 1: 0.31 (di chuyển) + 0.25 (nạp lại) + 2.55 (phục vụ) = 3.11h
#  Quận 0: Tổng quãng đường=31.28km, Thời gian di chuyển=0.63h
#  Quận 0: 0.63 (di chuyển) + 0.75 (nạp lại) + 4.69 (phục vụ) = 6.07h
#  Quận 1: Tổng quãng đường=17.70km, Thời gian di chuyển=0.35h
#  Quận 1: 0.35 (di chuyển) + 0.50 (nạp lại) + 2.66 (phục vụ) = 3.51h
#  Quận 0: Tổng quãng đường=32.62km, Thời gian di chuyển=0.65h
#  Quận 0: 0.65 (di chuyển) + 1.00 (nạp lại) + 4.80 (phục vụ) = 6.45h
#  Quận 1: Tổng quãng đường=15.74km, Thời gian di chuyển=0.31h
#  Quận 1: 0.31 (di chuyển) + 0.25 (nạp lại) + 2.55 (phục vụ) = 3.11h
#  Quận 0: Tổng quãng đường=33.15km, Thời gian di chuyển=0.66h
#  Quận 0: 0.66 (di chuyển) + 1.00 (nạp lại) + 4.86 (phục vụ) = 6.52h
#  Quận 1: Tổng quãng đường=15.60km, Thời gian di chuyển=0.31h
#  Quận 1: 0.31 (di chuyển) + 0.25 (nạp lại) + 2.49 (phục vụ) = 3.05h
#  Quận 0: Tổng quãng đường=30.53km, Thời gian di chuyển=0.61h
#  Quận 0: 0.61 (di chuyển) + 0.75 (nạp lại) + 4.55 (phục vụ) = 5.91h
#  Quận 1: Tổng quãng đường=18.73km, Thời gian di chuyển=0.37h
#  Quận 1: 0.37 (di chuyển) + 0.50 (nạp lại) + 2.80 (phục vụ) = 3.67h
#  Quận 0: Tổng quãng đường=31.87km, Thời gian di chuyển=0.64h
#  Quận 0: 0.64 (di chuyển) + 1.00 (nạp lại) + 4.66 (phục vụ) = 6.30h
#  Quận 1: Tổng quãng đường=16.93km, Thời gian di chuyển=0.34h
#  Quận 1: 0.34 (di chuyển) + 0.25 (nạp lại) + 2.69 (phục vụ) = 3.28h
#  Quận 0: Tổng quãng đường=32.37km, Thời gian di chuyển=0.65h
#  Quận 0: 0.65 (di chuyển) + 1.00 (nạp lại) + 4.72 (phục vụ) = 6.37h
#  Quận 1: Tổng quãng đường=16.79km, Thời gian di chuyển=0.34h
#  Quận 1: 0.34 (di chuyển) + 0.25 (nạp lại) + 2.63 (phục vụ) = 3.22h
#  Quận 0: Tổng quãng đường=31.28km, Thời gian di chuyển=0.63h
#  Quận 0: 0.63 (di chuyển) + 0.75 (nạp lại) + 4.69 (phục vụ) = 6.07h
#  Quận 1: Tổng quãng đường=17.70km, Thời gian di chuyển=0.35h
#  Quận 1: 0.35 (di chuyển) + 0.50 (nạp lại) + 2.66 (phục vụ) = 3.51h
#  Quận 0: Tổng quãng đường=31.71km, Thời gian di chuyển=0.63h
#  Quận 0: 0.63 (di chuyển) + 0.75 (nạp lại) + 4.71 (phục vụ) = 6.09h
#  Quận 1: Tổng quãng đường=17.06km, Thời gian di chuyển=0.34h
#  Quận 1: 0.34 (di chuyển) + 0.25 (nạp lại) + 2.64 (phục vụ) = 3.23h
#  Quận 0: Tổng quãng đường=30.89km, Thời gian di chuyển=0.62h
#  Quận 0: 0.62 (di chuyển) + 0.75 (nạp lại) + 4.73 (phục vụ) = 6.10h
#  Quận 1: Tổng quãng đường=17.55km, Thời gian di chuyển=0.35h
#  Quận 1: 0.35 (di chuyển) + 0.25 (nạp lại) + 2.62 (phục vụ) = 3.22h
#  Quận 0: Tổng quãng đường=29.50km, Thời gian di chuyển=0.59h
#  Quận 0: 0.59 (di chuyển) + 0.75 (nạp lại) + 4.43 (phục vụ) = 5.77h
#  Quận 1: Tổng quãng đường=19.82km, Thời gian di chuyển=0.40h
#  Quận 1: 0.40 (di chuyển) + 0.50 (nạp lại) + 2.92 (phục vụ) = 3.82h
#  Quận 0: Tổng quãng đường=30.21km, Thời gian di chuyển=0.60h
#  Quận 0: 0.60 (di chuyển) + 0.75 (nạp lại) + 4.54 (phục vụ) = 5.89h
#  Quận 1: Tổng quãng đường=18.90km, Thời gian di chuyển=0.38h
#  Quận 1: 0.38 (di chuyển) + 0.50 (nạp lại) + 2.81 (phục vụ) = 3.69h
#  Quận 0: Tổng quãng đường=30.75km, Thời gian di chuyển=0.62h
#  Quận 0: 0.62 (di chuyển) + 0.75 (nạp lại) + 4.60 (phục vụ) = 5.97h
#  Quận 1: Tổng quãng đường=18.65km, Thời gian di chuyển=0.37h
#  Quận 1: 0.37 (di chuyển) + 0.50 (nạp lại) + 2.75 (phục vụ) = 3.62h
#  Quận 0: Tổng quãng đường=30.28km, Thời gian di chuyển=0.61h
#  Quận 0: 0.61 (di chuyển) + 0.75 (nạp lại) + 4.57 (phục vụ) = 5.93h
#  Quận 1: Tổng quãng đường=18.83km, Thời gian di chuyển=0.38h
#  Quận 1: 0.38 (di chuyển) + 0.50 (nạp lại) + 2.78 (phục vụ) = 3.66h
#  Quận 0: Tổng quãng đường=30.67km, Thời gian di chuyển=0.61h
#  Quận 0: 0.61 (di chuyển) + 0.75 (nạp lại) + 4.59 (phục vụ) = 5.95h
#  Quận 1: Tổng quãng đường=18.78km, Thời gian di chuyển=0.38h
#  Quận 1: 0.38 (di chuyển) + 0.50 (nạp lại) + 2.76 (phục vụ) = 3.64h
#  Quận 0: Tổng quãng đường=29.87km, Thời gian di chuyển=0.60h
#  Quận 0: 0.60 (di chuyển) + 0.75 (nạp lại) + 4.61 (phục vụ) = 5.96h
#  Quận 1: Tổng quãng đường=19.46km, Thời gian di chuyển=0.39h
#  Quận 1: 0.39 (di chuyển) + 0.50 (nạp lại) + 2.74 (phục vụ) = 3.63h
#  Quận 0: Tổng quãng đường=30.53km, Thời gian di chuyển=0.61h
#  Quận 0: 0.61 (di chuyển) + 0.75 (nạp lại) + 4.55 (phục vụ) = 5.91h
#  Quận 1: Tổng quãng đường=18.73km, Thời gian di chuyển=0.37h
#  Quận 1: 0.37 (di chuyển) + 0.50 (nạp lại) + 2.80 (phục vụ) = 3.67h
#  Quận 0: Tổng quãng đường=28.92km, Thời gian di chuyển=0.58h
#  Quận 0: 0.58 (di chuyển) + 0.75 (nạp lại) + 4.29 (phục vụ) = 5.62h
#  Quận 1: Tổng quãng đường=20.48km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.06 (phục vụ) = 3.97h
#  Quận 0: Tổng quãng đường=29.61km, Thời gian di chuyển=0.59h
#  Quận 0: 0.59 (di chuyển) + 0.75 (nạp lại) + 4.40 (phục vụ) = 5.74h
#  Quận 1: Tổng quãng đường=19.54km, Thời gian di chuyển=0.39h
#  Quận 1: 0.39 (di chuyển) + 0.50 (nạp lại) + 2.95 (phục vụ) = 3.84h
#  Quận 0: Tổng quãng đường=30.15km, Thời gian di chuyển=0.60h
#  Quận 0: 0.60 (di chuyển) + 0.75 (nạp lại) + 4.46 (phục vụ) = 5.81h
#  Quận 1: Tổng quãng đường=19.28km, Thời gian di chuyển=0.39h
#  Quận 1: 0.39 (di chuyển) + 0.50 (nạp lại) + 2.89 (phục vụ) = 3.78h
#  Quận 0: Tổng quãng đường=29.67km, Thời gian di chuyển=0.59h
#  Quận 0: 0.59 (di chuyển) + 0.75 (nạp lại) + 4.43 (phục vụ) = 5.77h
#  Quận 1: Tổng quãng đường=19.48km, Thời gian di chuyển=0.39h
#  Quận 1: 0.39 (di chuyển) + 0.50 (nạp lại) + 2.92 (phục vụ) = 3.81h
#  Quận 0: Tổng quãng đường=30.09km, Thời gian di chuyển=0.60h
#  Quận 0: 0.60 (di chuyển) + 0.75 (nạp lại) + 4.45 (phục vụ) = 5.80h
#  Quận 1: Tổng quãng đường=19.45km, Thời gian di chuyển=0.39h
#  Quận 1: 0.39 (di chuyển) + 0.50 (nạp lại) + 2.90 (phục vụ) = 3.79h
#  Quận 0: Tổng quãng đường=27.72km, Thời gian di chuyển=0.55h
#  Quận 0: 0.55 (di chuyển) + 0.75 (nạp lại) + 4.15 (phục vụ) = 5.45h
#  Quận 1: Tổng quãng đường=21.68km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.20 (phục vụ) = 4.13h
#  Quận 0: Tổng quãng đường=28.39km, Thời gian di chuyển=0.57h
#  Quận 0: 0.57 (di chuyển) + 0.75 (nạp lại) + 4.26 (phục vụ) = 5.58h
#  Quận 1: Tổng quãng đường=20.73km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.09 (phục vụ) = 4.00h
#  Quận 0: Tổng quãng đường=28.95km, Thời gian di chuyển=0.58h
#  Quận 0: 0.58 (di chuyển) + 0.75 (nạp lại) + 4.32 (phục vụ) = 5.65h
#  Quận 1: Tổng quãng đường=20.47km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.03 (phục vụ) = 3.94h
#  Quận 0: Tổng quãng đường=28.46km, Thời gian di chuyển=0.57h
#  Quận 0: 0.57 (di chuyển) + 0.75 (nạp lại) + 4.29 (phục vụ) = 5.61h
#  Quận 1: Tổng quãng đường=20.66km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.06 (phục vụ) = 3.97h
# ...
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.98 (phục vụ) = 5.23h
#  Quận 0: Tổng quãng đường=23.18km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.31 (phục vụ) = 4.27h
#  Quận 1: Tổng quãng đường=25.55km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 4.04 (phục vụ) = 5.30h
#  Quận 0: Tổng quãng đường=23.45km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.34 (phục vụ) = 4.31h
#  Quận 1: Tổng quãng đường=25.11km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.50 (nạp lại) + 4.01 (phục vụ) = 5.01h
#  Quận 0: Tổng quãng đường=23.09km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.32 (phục vụ) = 4.28h
#  Quận 1: Tổng quãng đường=25.37km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 4.03 (phục vụ) = 5.29h
#  Quận 0: Tổng quãng đường=23.03km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.34 (phục vụ) = 4.30h
#  Quận 1: Tổng quãng đường=25.48km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 4.01 (phục vụ) = 5.27h
#  Quận 0: Tổng quãng đường=24.07km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.30 (phục vụ) = 4.28h
#  Quận 1: Tổng quãng đường=24.47km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.75 (nạp lại) + 4.05 (phục vụ) = 5.29h
#  Quận 0: Tổng quãng đường=23.32km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.36 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=25.38km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.99 (phục vụ) = 5.25h
#  Quận 0: Tổng quãng đường=23.26km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.30 (phục vụ) = 4.27h
#  Quận 1: Tổng quãng đường=25.43km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 4.05 (phục vụ) = 5.31h
#  Quận 0: Tổng quãng đường=23.30km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.37 (phục vụ) = 4.34h
#  Quận 1: Tổng quãng đường=25.12km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.98 (phục vụ) = 5.23h
#  Quận 0: Tổng quãng đường=23.19km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.30 (phục vụ) = 4.26h
#  Quận 1: Tổng quãng đường=25.52km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 4.05 (phục vụ) = 5.31h
#  Quận 0: Tổng quãng đường=23.55km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.35 (phục vụ) = 4.32h
#  Quận 1: Tổng quãng đường=25.11km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 4.00 (phục vụ) = 5.25h
#  Quận 0: Tổng quãng đường=23.03km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.34 (phục vụ) = 4.30h
#  Quận 1: Tổng quãng đường=25.44km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 4.01 (phục vụ) = 5.27h
#  Quận 0: Tổng quãng đường=23.09km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.36 (phục vụ) = 4.32h
#  Quận 1: Tổng quãng đường=25.36km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.99 (phục vụ) = 5.25h
#  Quận 0: Tổng quãng đường=22.71km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.36 (phục vụ) = 4.31h
#  Quận 1: Tổng quãng đường=25.85km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.99 (phục vụ) = 5.26h
#  Quận 0: Tổng quãng đường=24.10km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.36 (phục vụ) = 4.34h
#  Quận 1: Tổng quãng đường=24.40km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.99 (phục vụ) = 4.98h
#  Quận 0: Tổng quãng đường=23.20km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.37 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=25.22km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.98 (phục vụ) = 5.23h
#  Quận 0: Tổng quãng đường=25.31km, Thời gian di chuyển=0.51h
#  Quận 0: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.60 (phục vụ) = 4.86h
#  Quận 1: Tổng quãng đường=23.38km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.75 (phục vụ) = 4.72h
#  Quận 0: Tổng quãng đường=24.26km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.48h
#  Quận 1: Tổng quãng đường=24.42km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.86 (phục vụ) = 4.85h
#  Quận 0: Tổng quãng đường=23.92km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.43 (phục vụ) = 4.41h
#  Quận 1: Tổng quãng đường=24.76km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.50 (nạp lại) + 3.92 (phục vụ) = 4.92h
#  Quận 0: Tổng quãng đường=24.34km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.46 (phục vụ) = 4.70h
#  Quận 1: Tổng quãng đường=24.51km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.89 (phục vụ) = 4.88h
#  Quận 0: Tổng quãng đường=23.90km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.42h
#  Quận 1: Tổng quãng đường=24.52km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.91 (phục vụ) = 4.90h
#  Quận 0: Tổng quãng đường=23.82km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.46 (phục vụ) = 4.44h
#  Quận 1: Tổng quãng đường=24.77km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.50 (nạp lại) + 3.89 (phục vụ) = 4.89h
#  Quận 0: Tổng quãng đường=25.05km, Thời gian di chuyển=0.50h
#  Quận 0: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.42 (phục vụ) = 4.67h
#  Quận 1: Tổng quãng đường=23.73km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.93 (phục vụ) = 4.90h
#  Quận 0: Tổng quãng đường=24.04km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.46h
#  Quận 1: Tổng quãng đường=24.76km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.87 (phục vụ) = 5.12h
#  Quận 0: Tổng quãng đường=24.01km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.42 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=24.65km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.93 (phục vụ) = 4.92h
#  Quận 0: Tổng quãng đường=24.10km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.47h
#  Quận 1: Tổng quãng đường=24.28km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.86 (phục vụ) = 4.85h
#  Quận 0: Tổng quãng đường=23.90km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.42 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=24.93km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.93 (phục vụ) = 5.18h
#  Quận 0: Tổng quãng đường=24.28km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.46h
#  Quận 1: Tổng quãng đường=24.38km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.88 (phục vụ) = 4.87h
#  Quận 0: Tổng quãng đường=23.84km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.46 (phục vụ) = 4.44h
#  Quận 1: Tổng quãng đường=24.59km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.89 (phục vụ) = 4.88h
#  Quận 0: Tổng quãng đường=23.91km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.46h
#  Quận 1: Tổng quãng đường=24.51km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.86h
#  Quận 0: Tổng quãng đường=23.52km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.45h
#  Quận 1: Tổng quãng đường=24.98km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.87h
#  Quận 0: Tổng quãng đường=25.05km, Thời gian di chuyển=0.50h
#  Quận 0: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.48 (phục vụ) = 4.73h
#  Quận 1: Tổng quãng đường=23.75km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.84h
#  Quận 0: Tổng quãng đường=24.01km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.47h
#  Quận 1: Tổng quãng đường=24.45km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.86 (phục vụ) = 5.10h
#  Quận 0: Tổng quãng đường=24.32km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.47h
#  Quận 1: Tổng quãng đường=24.08km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.85h
#  Quận 0: Tổng quãng đường=25.86km, Thời gian di chuyển=0.52h
#  Quận 0: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.73 (phục vụ) = 5.00h
#  Quận 1: Tổng quãng đường=22.95km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.62 (phục vụ) = 4.58h
#  Quận 0: Tổng quãng đường=25.69km, Thời gian di chuyển=0.51h
#  Quận 0: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.72 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=23.10km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.63 (phục vụ) = 4.59h
#  Quận 0: Tổng quãng đường=26.45km, Thời gian di chuyển=0.53h
#  Quận 0: 0.53 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 5.06h
#  Quận 1: Tổng quãng đường=22.40km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.52h
#  Quận 0: Tổng quãng đường=26.42km, Thời gian di chuyển=0.53h
#  Quận 0: 0.53 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 5.06h
#  Quận 1: Tổng quãng đường=22.33km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.52h
#  Quận 0: Tổng quãng đường=26.37km, Thời gian di chuyển=0.53h
#  Quận 0: 0.53 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 5.05h
#  Quận 1: Tổng quãng đường=22.51km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.53h
#  Quận 0: Tổng quãng đường=24.73km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.42 (phục vụ) = 4.41h
#  Quận 1: Tổng quãng đường=23.84km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.93 (phục vụ) = 4.91h
#  Quận 0: Tổng quãng đường=26.45km, Thời gian di chuyển=0.53h
#  Quận 0: 0.53 (di chuyển) + 0.75 (nạp lại) + 3.75 (phục vụ) = 5.03h
#  Quận 1: Tổng quãng đường=22.44km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.60 (phục vụ) = 4.55h
#  Quận 0: Tổng quãng đường=26.54km, Thời gian di chuyển=0.53h
#  Quận 0: 0.53 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 5.06h
#  Quận 1: Tổng quãng đường=22.33km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.52h
#  Quận 0: Tổng quãng đường=26.47km, Thời gian di chuyển=0.53h
#  Quận 0: 0.53 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 5.06h
#  Quận 1: Tổng quãng đường=22.24km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.51h
#  Quận 0: Tổng quãng đường=26.39km, Thời gian di chuyển=0.53h
#  Quận 0: 0.53 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 5.06h
#  Quận 1: Tổng quãng đường=22.51km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.52h
#  Quận 0: Tổng quãng đường=24.09km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.42h
#  Quận 1: Tổng quãng đường=24.61km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.91 (phục vụ) = 4.90h
#  Quận 0: Tổng quãng đường=26.58km, Thời gian di chuyển=0.53h
#  Quận 0: 0.53 (di chuyển) + 0.75 (nạp lại) + 3.72 (phục vụ) = 5.00h
#  Quận 1: Tổng quãng đường=22.26km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.63 (phục vụ) = 4.58h
#  Quận 0: Tổng quãng đường=26.40km, Thời gian di chuyển=0.53h
#  Quận 0: 0.53 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 5.05h
#  Quận 1: Tổng quãng đường=22.50km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.53h
#  Quận 0: Tổng quãng đường=26.22km, Thời gian di chuyển=0.52h
#  Quận 0: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=22.53km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.59h
#  Quận 0: Tổng quãng đường=26.10km, Thời gian di chuyển=0.52h
#  Quận 0: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.75 (phục vụ) = 5.02h
#  Quận 1: Tổng quãng đường=22.66km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.60 (phục vụ) = 4.55h
#  Quận 0: Tổng quãng đường=26.27km, Thời gian di chuyển=0.53h
#  Quận 0: 0.53 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 5.05h
#  Quận 1: Tổng quãng đường=22.59km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.53h
#  Quận 0: Tổng quãng đường=23.92km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.46 (phục vụ) = 4.44h
#  Quận 1: Tổng quãng đường=24.81km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.50 (nạp lại) + 3.89 (phục vụ) = 4.89h
#  Quận 0: Tổng quãng đường=26.03km, Thời gian di chuyển=0.52h
#  Quận 0: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=22.69km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.59h
#  Quận 0: Tổng quãng đường=26.78km, Thời gian di chuyển=0.54h
#  Quận 0: 0.54 (di chuyển) + 0.75 (nạp lại) + 3.72 (phục vụ) = 5.01h
#  Quận 1: Tổng quãng đường=22.13km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.63 (phục vụ) = 4.57h
#  Quận 0: Tổng quãng đường=26.48km, Thời gian di chuyển=0.53h
#  Quận 0: 0.53 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=22.25km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.58h
#  Quận 0: Tổng quãng đường=26.10km, Thời gian di chuyển=0.52h
#  Quận 0: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.72 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=22.66km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.63 (phục vụ) = 4.58h
#  Quận 0: Tổng quãng đường=25.84km, Thời gian di chuyển=0.52h
#  Quận 0: 0.52 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 5.04h
#  Quận 1: Tổng quãng đường=22.96km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.54h
#  Quận 0: Tổng quãng đường=23.84km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.42 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=25.01km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.93 (phục vụ) = 5.18h
#  Quận 0: Tổng quãng đường=23.47km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.43 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=25.47km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.92 (phục vụ) = 5.18h
#  Quận 0: Tổng quãng đường=23.92km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.43 (phục vụ) = 4.41h
#  Quận 1: Tổng quãng đường=24.92km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.92 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=26.42km, Thời gian di chuyển=0.53h
#  Quận 0: 0.53 (di chuyển) + 0.75 (nạp lại) + 3.75 (phục vụ) = 5.03h
#  Quận 1: Tổng quãng đường=22.35km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.60 (phục vụ) = 4.55h
#  Quận 0: Tổng quãng đường=25.31km, Thời gian di chuyển=0.51h
#  Quận 0: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.60 (phục vụ) = 4.86h
#  Quận 1: Tổng quãng đường=23.38km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.75 (phục vụ) = 4.72h
#
# Kết quả VNS:
#  → Điểm cuối: 0.0848
#  → Cải thiện: 8.0%
#
# Trực quan hóa VNS...
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13540\4021880790.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('nipy_spectral', NUM_DISTRICTS)

# %%
print_strategic_plan(vns_solution, areas, vns_assignments, "VNS")
# Out:
# ================================================================================
#  KẾ HOẠCH CHIẾN THUẬT - Thuật toán: VNS
# ================================================================================
#  Quận 0: Tổng quãng đường=21.40km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.60 (phục vụ) = 4.78h
#  Quận 1: Tổng quãng đường=22.89km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.75 (phục vụ) = 4.71h
#
# ================================================================================================================================================================
# BẢNG TỔNG QUAN PHÂN CÔNG
# ================================================================================================================================================================
# Quận   Tài xế           Loại                 Xe               Khu vực    Tổng TG/Time     Bưu kiện/h     Trọng lượng        Chuyến   Tỷ lệ sử dụng
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# 0      2                Full-time            Xe máy to        24         4.78/8.0h        69.5 pcs/h     62.3/20 kg         4x       59.7%
# 1      1                Full-time            Xe máy to        26         4.71/8.0h        79.2 pcs/h     55.8/20 kg         3x       58.8%
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# TỔNG CỘNG                                          Workload: 7.35h  |  Bưu kiện/h: 74.3  |  Trọng lượng: 118.1kg  |  Tổng TG: 9.49h
# ================================================================================================================================================================

# %% [markdown]
# ### Local Search với Multi-Swap

# %%
### 3A-2. Local Search với Multi-Swap - Phiên bản mạnh mẽ ###
def local_search_multi_swap(initial_solution, areas, use_contiguity=True, swap_size=2):

    current_solution = list(initial_solution)
    current_score = calculate_objective_function_with_resources(current_solution, areas)
    
    initial_score = current_score
    best_solution = list(current_solution)
    best_score = current_score
    
    # Xây dựng đồ thị lân cận
    neighbor_graph = None
    if use_contiguity:
        neighbor_graph = build_neighbor_graph(areas)
    
    improved = True
    iteration = 0
    max_iterations = 50
    
    while improved and iteration < max_iterations:
        improved = False
        iteration += 1
        
        # CHIẾN LƯỢC 1: Di chuyển đơn lẻ (fast exploration)
        for _ in range(200): 
            area_idx = random.randint(0, len(areas) - 1)
            current_district = current_solution[area_idx]
            new_district = random.randint(0, NUM_DISTRICTS - 1)
            
            if new_district == current_district:
                continue
            
            neighbor_solution = list(current_solution)
            neighbor_solution[area_idx] = new_district
            
            # Kiểm tra contiguity
            if use_contiguity and neighbor_graph:
                if not is_contiguous(neighbor_solution, neighbor_graph, current_district):
                    continue
                if not is_contiguous(neighbor_solution, neighbor_graph, new_district):
                    continue
            
            neighbor_score = calculate_objective_function_with_resources(neighbor_solution, areas)
            
            if neighbor_score < current_score:
                current_solution = neighbor_solution
                current_score = neighbor_score
                improved = True
                break
        
        if improved:
            if current_score < best_score:
                best_solution = list(current_solution)
                best_score = current_score
            continue
        
        # CHIẾN LƯỢC 2: Swap ngẫu nhiên giữa các cặp quận
        district_pairs = [(a, b) for a in range(NUM_DISTRICTS) for b in range(a + 1, NUM_DISTRICTS)]
        random.shuffle(district_pairs)
        
        for district_a, district_b in district_pairs[:200]: 
            areas_a = [i for i, d in enumerate(current_solution) if d == district_a]
            areas_b = [i for i, d in enumerate(current_solution) if d == district_b]
            
            if len(areas_a) == 0 or len(areas_b) == 0:
                continue
            
            for _ in range(3):
                sample_size = min(swap_size, len(areas_a), len(areas_b))
                sample_a = random.sample(areas_a, sample_size)
                sample_b = random.sample(areas_b, sample_size)
                
                neighbor_solution = list(current_solution)
                for idx in sample_a:
                    neighbor_solution[idx] = district_b
                for idx in sample_b:
                    neighbor_solution[idx] = district_a
                
                if use_contiguity and neighbor_graph:
                    if not is_contiguous(neighbor_solution, neighbor_graph, district_a):
                        continue
                    if not is_contiguous(neighbor_solution, neighbor_graph, district_b):
                        continue
                
                neighbor_score = calculate_objective_function_with_resources(neighbor_solution, areas)
                
                if neighbor_score < current_score:
                    current_solution = neighbor_solution
                    current_score = neighbor_score
                    improved = True
                    break
            
            if improved:
                break
        
        if current_score < best_score:
            best_solution = list(current_solution)
            best_score = current_score
    
    # Sửa contiguity cuối cùng
    if use_contiguity and neighbor_graph:
        repaired_solution = repair_contiguous(list(best_solution), neighbor_graph)
        repaired_score = calculate_objective_function_with_resources(repaired_solution, areas)
        
        if repaired_score <= best_score:
            best_solution = repaired_solution
            best_score = repaired_score
    
    # Đảm bảo không tệ hơn initial
    if best_score > initial_score:
        return list(initial_solution), initial_score
    
    return best_solution, best_score

# %%
### 3B. Variable Neighborhood Search (VNS) với Contiguity ###
def shake_2(solution, k):
    new_solution = list(solution)
    
    # Lặp k lần để thực hiện shake mạnh hơn
    for _ in range(k):
        # Chọn ngẫu nhiên 1 quận để shake
        district_to_shake = random.randint(0, NUM_DISTRICTS - 1)
        
        # Lấy danh sách các khu vực thuộc quận này
        areas_in_district = [i for i, d in enumerate(new_solution) if d == district_to_shake]
        
        if len(areas_in_district) == 0:
            continue
        
        # Chuyển 20% số khu vực của quận này (tối thiểu 1 khu vực)
        num_areas_to_move = max(1, int(len(areas_in_district) * 0.20))
        
        # Chọn ngẫu nhiên các khu vực để di chuyển
        areas_to_move = random.sample(areas_in_district, min(num_areas_to_move, len(areas_in_district)))
        
        # Di chuyển các khu vực sang quận khác
        for area_idx in areas_to_move:
            # Chọn quận đích khác với quận hiện tại
            new_district = random.randint(0, NUM_DISTRICTS - 1)
            while new_district == district_to_shake and NUM_DISTRICTS > 1:
                new_district = random.randint(0, NUM_DISTRICTS - 1)
            new_solution[area_idx] = new_district
    
    return new_solution

def vns_2(initial_solution, areas, max_iter=4, k_max=4, use_contiguity=True):

    best_solution = list(initial_solution)
    best_score = calculate_objective_function_with_resources(best_solution, areas)
    
    # Xây dựng đồ thị lân cận
    neighbor_graph = None
    if use_contiguity:
        neighbor_graph = build_neighbor_graph(areas)

    for iteration in range(max_iter):
        k = 1
        while k <= k_max:
            # Shake với cường độ k
            shaken_solution = shake_2(best_solution, k)
            
            # Sửa contiguity cho solution sau khi shake
            if use_contiguity and neighbor_graph:
                shaken_solution = repair_contiguous(shaken_solution, neighbor_graph)
            
            # Local search để cải thiện
            improved_solution, improved_score = local_search_multi_swap(shaken_solution, areas, use_contiguity)
            # Nếu tìm được cải thiện
            if improved_score < best_score:
                best_solution = improved_solution
                best_score = improved_score
                print(f"VNS_2 Iter {iteration}, k={k}: New best = {best_score:.4f}")
                k = 1  # Reset về neighborhood nhỏ nhất
            else:
                k += 1  # Thử neighborhood lớn hơn
                
    return best_solution, best_score

print("Đã cập nhật VNS_2 với logic chuẩn")
# Out:
# Đã cập nhật VNS_2 với logic chuẩn

# %%
print("\n" + "="*80)
print("THUẬT TOÁN 1: LOCAL SEARCH 2")
print("="*80)

ls_solution_2, ls_score_2 = local_search_multi_swap(initial_solution, areas)

print(f"\nKết quả Local Search:")
print(f" → Điểm tốt nhất: {ls_score_2:.4f}")
print(f" → Cải thiện: {((initial_score - ls_score_2) / initial_score * 100):.1f}%")

ls_assignments_2, ls_stats_2 = assign_resources_to_districts(ls_solution_2, areas)

print("\nTrực quan hóa Local Search...")
plot_solution(ls_solution_2, areas, 
             f"LOCAL SEARCH - Score: {ls_score_2:.4f}")
# Out:
# ================================================================================
# THUẬT TOÁN 1: LOCAL SEARCH 2
# ================================================================================
#  Quận 0: Tổng quãng đường=24.53km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.86 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=20.07km, Thời gian di chuyển=0.40h
#  Quận 1: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.39h
#  Quận 0: Tổng quãng đường=25.00km, Thời gian di chuyển=0.50h
#  Quận 0: 0.50 (di chuyển) + 0.75 (nạp lại) + 4.04 (phục vụ) = 5.29h
#  Quận 1: Tổng quãng đường=19.43km, Thời gian di chuyển=0.39h
#  Quận 1: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.31 (phục vụ) = 4.20h
#  Quận 0: Tổng quãng đường=25.34km, Thời gian di chuyển=0.51h
#  Quận 0: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.97 (phục vụ) = 5.23h
#  Quận 1: Tổng quãng đường=18.68km, Thời gian di chuyển=0.37h
#  Quận 1: 0.37 (di chuyển) + 0.50 (nạp lại) + 3.38 (phục vụ) = 4.25h
#  Quận 0: Tổng quãng đường=23.55km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.75 (phục vụ) = 4.97h
#  Quận 1: Tổng quãng đường=21.08km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.60 (phục vụ) = 4.52h
#  Quận 0: Tổng quãng đường=23.22km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.64 (phục vụ) = 4.85h
#  Quận 1: Tổng quãng đường=22.29km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.71 (phục vụ) = 4.66h
#  Quận 0: Tổng quãng đường=24.14km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.92 (phục vụ) = 5.15h
#  Quận 1: Tổng quãng đường=20.65km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.43 (phục vụ) = 4.34h
#  Quận 0: Tổng quãng đường=24.39km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.86 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=19.68km, Thời gian di chuyển=0.39h
#  Quận 1: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.38h
#  Quận 0: Tổng quãng đường=22.85km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.63 (phục vụ) = 4.84h
#  Quận 1: Tổng quãng đường=22.11km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.72 (phục vụ) = 4.66h
#  Quận 0: Tổng quãng đường=23.71km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.75 (phục vụ) = 4.97h
#  Quận 1: Tổng quãng đường=21.98km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.60 (phục vụ) = 4.54h
#  Quận 0: Tổng quãng đường=20.87km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.45 (phục vụ) = 4.37h
#  Quận 1: Tổng quãng đường=23.50km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.90 (phục vụ) = 4.87h
#  Quận 0: Tổng quãng đường=24.24km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.75 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=20.66km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.60 (phục vụ) = 4.51h
#  Quận 0: Tổng quãng đường=23.46km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.80 (phục vụ) = 5.02h
#  Quận 1: Tổng quãng đường=21.70km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.48h
#  Quận 0: Tổng quãng đường=21.20km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.52 (phục vụ) = 4.44h
#  Quận 1: Tổng quãng đường=23.29km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.83 (phục vụ) = 4.80h
#  Quận 0: Tổng quãng đường=23.64km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.74 (phục vụ) = 4.96h
#  Quận 1: Tổng quãng đường=20.70km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.52h
#  Quận 0: Tổng quãng đường=21.45km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.52h
#  Quận 1: Tổng quãng đường=21.73km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.76 (phục vụ) = 4.69h
#  Quận 0: Tổng quãng đường=20.84km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=24.06km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=20.92km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=24.04km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=23.64km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.74 (phục vụ) = 4.96h
#  Quận 1: Tổng quãng đường=20.70km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.52h
#  Quận 0: Tổng quãng đường=20.92km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=24.04km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=23.48km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=20.69km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.55h
#  Quận 0: Tổng quãng đường=20.22km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.31h
#  Quận 1: Tổng quãng đường=23.93km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=23.77km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.70 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=20.73km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.65 (phục vụ) = 4.56h
#  Quận 0: Tổng quãng đường=23.71km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.70 (phục vụ) = 4.92h
#  Quận 1: Tổng quãng đường=20.92km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.65 (phục vụ) = 4.57h
#  Quận 0: Tổng quãng đường=20.33km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.42 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=23.96km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.93 (phục vụ) = 5.16h
#  Quận 0: Tổng quãng đường=23.35km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=21.10km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.50h
#  Quận 0: Tổng quãng đường=20.39km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.32h
#  Quận 1: Tổng quãng đường=23.86km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=23.76km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.94h
#  Quận 1: Tổng quãng đường=21.61km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.57h
#  Quận 0: Tổng quãng đường=21.20km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.45 (phục vụ) = 4.37h
#  Quận 1: Tổng quãng đường=22.98km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.90 (phục vụ) = 4.86h
#  Quận 0: Tổng quãng đường=23.76km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.94h
#  Quận 1: Tổng quãng đường=21.61km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.57h
#  Quận 0: Tổng quãng đường=23.77km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.70 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=20.73km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.65 (phục vụ) = 4.56h
#  Quận 0: Tổng quãng đường=20.94km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.43 (phục vụ) = 4.35h
#  Quận 1: Tổng quãng đường=23.93km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.92 (phục vụ) = 5.15h
#  Quận 0: Tổng quãng đường=20.84km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=24.06km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=20.22km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.31h
#  Quận 1: Tổng quãng đường=23.93km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=20.18km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.31h
#  Quận 1: Tổng quãng đường=24.02km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=19.99km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.43 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=24.22km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.92 (phục vụ) = 5.15h
#  Quận 0: Tổng quãng đường=20.18km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.31h
#  Quận 1: Tổng quãng đường=24.02km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=19.78km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.45 (phục vụ) = 4.35h
#  Quận 1: Tổng quãng đường=23.97km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.90 (phục vụ) = 5.13h
#  Quận 0: Tổng quãng đường=21.20km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.45 (phục vụ) = 4.37h
#  Quận 1: Tổng quãng đường=22.98km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.90 (phục vụ) = 4.86h
#  Quận 0: Tổng quãng đường=23.64km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.74 (phục vụ) = 4.96h
#  Quận 1: Tổng quãng đường=20.70km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.52h
#  Quận 0: Tổng quãng đường=23.76km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.94h
#  Quận 1: Tổng quãng đường=21.61km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.57h
#  Quận 0: Tổng quãng đường=20.79km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=23.99km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=20.79km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=23.99km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=23.76km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.94h
#  Quận 1: Tổng quãng đường=21.61km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.57h
#  Quận 0: Tổng quãng đường=20.71km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.39h
#  Quận 1: Tổng quãng đường=23.13km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.83h
#  Quận 0: Tổng quãng đường=23.35km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=21.10km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.50h
#  Quận 0: Tổng quãng đường=23.48km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=20.69km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.55h
#  Quận 0: Tổng quãng đường=20.82km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=24.11km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=24.20km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.94h
#  Quận 1: Tổng quãng đường=20.30km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.55h
#  Quận 0: Tổng quãng đường=20.79km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=23.99km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=23.77km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.70 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=20.73km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.65 (phục vụ) = 4.56h
#  Quận 0: Tổng quãng đường=21.24km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=23.80km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.87 (phục vụ) = 5.10h
#  Quận 0: Tổng quãng đường=23.35km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=21.10km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.50h
#  Quận 0: Tổng quãng đường=20.80km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.39h
#  Quận 1: Tổng quãng đường=23.94km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.11h
#  Quận 0: Tổng quãng đường=23.64km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=20.70km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.55h
#  Quận 0: Tổng quãng đường=23.64km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=20.70km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.55h
#  Quận 0: Tổng quãng đường=23.21km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.92h
#  Quận 1: Tổng quãng đường=21.01km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.56h
#  Quận 0: Tổng quãng đường=23.77km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.70 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=20.73km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.65 (phục vụ) = 4.56h
#  Quận 0: Tổng quãng đường=20.22km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.31h
#  Quận 1: Tổng quãng đường=23.93km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=24.20km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.94h
#  Quận 1: Tổng quãng đường=20.30km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.55h
#  Quận 0: Tổng quãng đường=23.76km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.94h
#  Quận 1: Tổng quãng đường=21.61km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.57h
#  Quận 0: Tổng quãng đường=24.20km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.94h
#  Quận 1: Tổng quãng đường=20.30km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.55h
#  Quận 0: Tổng quãng đường=20.61km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.43 (phục vụ) = 4.34h
#  Quận 1: Tổng quãng đường=23.50km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.92 (phục vụ) = 5.14h
#  Quận 0: Tổng quãng đường=20.22km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.31h
#  Quận 1: Tổng quãng đường=23.93km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=20.61km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.43 (phục vụ) = 4.34h
#  Quận 1: Tổng quãng đường=23.50km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.92 (phục vụ) = 5.14h
#  Quận 0: Tổng quãng đường=20.92km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=24.04km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=23.83km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.73 (phục vụ) = 4.96h
#  Quận 1: Tổng quãng đường=21.05km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.62 (phục vụ) = 4.54h
#  Quận 0: Tổng quãng đường=21.24km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=23.80km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.87 (phục vụ) = 5.10h
#  Quận 0: Tổng quãng đường=20.84km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=24.06km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=21.24km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=23.80km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.87 (phục vụ) = 5.10h
#  Quận 0: Tổng quãng đường=20.79km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=23.99km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=20.92km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.46 (phục vụ) = 4.38h
#  Quận 1: Tổng quãng đường=23.74km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.89 (phục vụ) = 5.11h
#  Quận 0: Tổng quãng đường=20.26km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.38h
#  Quận 1: Tổng quãng đường=23.03km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.88 (phục vụ) = 4.84h
#  Quận 0: Tổng quãng đường=23.77km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.70 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=20.73km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.65 (phục vụ) = 4.56h
#  Quận 0: Tổng quãng đường=20.33km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.42 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=23.96km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.93 (phục vụ) = 5.16h
#  Quận 0: Tổng quãng đường=23.48km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=20.69km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.55h
#  Quận 0: Tổng quãng đường=23.39km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.66 (phục vụ) = 4.88h
#  Quận 1: Tổng quãng đường=22.62km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.69 (phục vụ) = 4.64h
#  Quận 0: Tổng quãng đường=21.45km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.52h
#  Quận 1: Tổng quãng đường=21.73km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.76 (phục vụ) = 4.69h
#
# Kết quả Local Search:
#  → Điểm tốt nhất: 0.0862
#  → Cải thiện: 6.4%
#
# Trực quan hóa Local Search...
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13540\4021880790.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('nipy_spectral', NUM_DISTRICTS)

# %%
print_strategic_plan(ls_solution_2, areas, ls_assignments_2, "LOCAL SEARCH 2")
# Out:
# ================================================================================
#  KẾ HOẠCH CHIẾN THUẬT - Thuật toán: LOCAL SEARCH 2
# ================================================================================
#  Quận 0: Tổng quãng đường=21.45km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.52h
#  Quận 1: Tổng quãng đường=21.73km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.76 (phục vụ) = 4.69h
#
# ================================================================================================================================================================
# BẢNG TỔNG QUAN PHÂN CÔNG
# ================================================================================================================================================================
# Quận   Tài xế           Loại                 Xe               Khu vực    Tổng TG/Time     Bưu kiện/h     Trọng lượng        Chuyến   Tỷ lệ sử dụng
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# 0      2                Full-time            Xe máy to        23         4.52/8.0h        73.2 pcs/h     59.7/20 kg         3x       56.5%
# 1      1                Full-time            Xe máy to        27         4.69/8.0h        79.7 pcs/h     58.5/20 kg         3x       58.7%
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# TỔNG CỘNG                                          Workload: 7.35h  |  Bưu kiện/h: 76.5  |  Trọng lượng: 118.1kg  |  Tổng TG: 9.21h
# ================================================================================================================================================================

# %%
# =============================================================================
# BƯỚC 3: CHẠY VNS
# =============================================================================

print("\n" + "="*80)
print("THUẬT TOÁN 2: VNS (Variable Neighborhood Search)")
print("="*80)

vns_solution_2, vns_score_2 = vns_2(initial_solution, areas)

print(f"\nKết quả VNS:")
print(f" → Điểm cuối: {vns_score_2:.4f}")
print(f" → Cải thiện: {((initial_score - vns_score_2) / initial_score * 100):.1f}%")

vns_assignments_2, vns_stats_2 = assign_resources_to_districts(vns_solution_2, areas)

print("\nTrực quan hóa VNS...")
plot_solution(vns_solution_2, areas, 
             f"VNS - Score: {vns_score_2:.4f}")
# Out:
# ================================================================================
# THUẬT TOÁN 2: VNS (Variable Neighborhood Search)
# ================================================================================
#  Quận 0: Tổng quãng đường=24.53km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.86 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=20.07km, Thời gian di chuyển=0.40h
#  Quận 1: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.39h
#  Quận 0: Tổng quãng đường=18.63km, Thời gian di chuyển=0.37h
#  Quận 0: 0.37 (di chuyển) + 0.50 (nạp lại) + 3.21 (phục vụ) = 4.08h
#  Quận 1: Tổng quãng đường=26.37km, Thời gian di chuyển=0.53h
#  Quận 1: 0.53 (di chuyển) + 0.50 (nạp lại) + 4.14 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=17.49km, Thời gian di chuyển=0.35h
#  Quận 0: 0.35 (di chuyển) + 0.50 (nạp lại) + 3.04 (phục vụ) = 3.89h
#  Quận 1: Tổng quãng đường=28.85km, Thời gian di chuyển=0.58h
#  Quận 1: 0.58 (di chuyển) + 0.75 (nạp lại) + 4.31 (phục vụ) = 5.64h
#  Quận 0: Tổng quãng đường=19.15km, Thời gian di chuyển=0.38h
#  Quận 0: 0.38 (di chuyển) + 0.50 (nạp lại) + 3.39 (phục vụ) = 4.27h
#  Quận 1: Tổng quãng đường=25.82km, Thời gian di chuyển=0.52h
#  Quận 1: 0.52 (di chuyển) + 0.50 (nạp lại) + 3.96 (phục vụ) = 4.98h
#  Quận 0: Tổng quãng đường=18.46km, Thời gian di chuyển=0.37h
#  Quận 0: 0.37 (di chuyển) + 0.50 (nạp lại) + 3.21 (phục vụ) = 4.08h
#  Quận 1: Tổng quãng đường=27.98km, Thời gian di chuyển=0.56h
#  Quận 1: 0.56 (di chuyển) + 0.75 (nạp lại) + 4.14 (phục vụ) = 5.45h
#  Quận 0: Tổng quãng đường=21.26km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.51 (phục vụ) = 4.69h
#  Quận 1: Tổng quãng đường=25.72km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.50 (nạp lại) + 3.84 (phục vụ) = 4.85h
#  Quận 0: Tổng quãng đường=21.91km, Thời gian di chuyển=0.44h
#  Quận 0: 0.44 (di chuyển) + 0.75 (nạp lại) + 3.65 (phục vụ) = 4.84h
#  Quận 1: Tổng quãng đường=24.20km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.70 (phục vụ) = 4.68h
#  Quận 0: Tổng quãng đường=21.11km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.47 (phục vụ) = 4.64h
#  Quận 1: Tổng quãng đường=25.70km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.50 (nạp lại) + 3.88 (phục vụ) = 4.89h
#  Quận 0: Tổng quãng đường=22.28km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.79 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=22.87km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.56 (phục vụ) = 4.52h
#  Quận 0: Tổng quãng đường=23.25km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.92 (phục vụ) = 5.13h
#  Quận 1: Tổng quãng đường=22.65km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.43 (phục vụ) = 4.38h
#  Quận 0: Tổng quãng đường=21.95km, Thời gian di chuyển=0.44h
#  Quận 0: 0.44 (di chuyển) + 0.75 (nạp lại) + 3.68 (phục vụ) = 4.87h
#  Quận 1: Tổng quãng đường=24.13km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.67 (phục vụ) = 4.65h
#  Quận 0: Tổng quãng đường=22.56km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.91 (phục vụ) = 5.11h
#  Quận 1: Tổng quãng đường=22.09km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.38h
#  Quận 0: Tổng quãng đường=23.47km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.91 (phục vụ) = 5.13h
#  Quận 1: Tổng quãng đường=21.55km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.44 (phục vụ) = 4.37h
#  Quận 0: Tổng quãng đường=21.59km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.61 (phục vụ) = 4.79h
#  Quận 1: Tổng quãng đường=24.40km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.74 (phục vụ) = 4.73h
#  Quận 0: Tổng quãng đường=21.49km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.61 (phục vụ) = 4.79h
#  Quận 1: Tổng quãng đường=24.47km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.74 (phục vụ) = 4.73h
#  Quận 0: Tổng quãng đường=23.14km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.90 (phục vụ) = 5.11h
#  Quận 1: Tổng quãng đường=22.05km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.45 (phục vụ) = 4.39h
#  Quận 0: Tổng quãng đường=21.79km, Thời gian di chuyển=0.44h
#  Quận 0: 0.44 (di chuyển) + 0.75 (nạp lại) + 3.61 (phục vụ) = 4.80h
#  Quận 1: Tổng quãng đường=23.51km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.74 (phục vụ) = 4.71h
#  Quận 0: Tổng quãng đường=22.69km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=23.22km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.53h
#  Quận 0: Tổng quãng đường=21.17km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.48 (phục vụ) = 4.65h
#  Quận 1: Tổng quãng đường=24.63km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.86h
#  Quận 0: Tổng quãng đường=21.00km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.43 (phục vụ) = 4.60h
#  Quận 1: Tổng quãng đường=25.06km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.50 (nạp lại) + 3.92 (phục vụ) = 4.92h
#  Quận 0: Tổng quãng đường=21.11km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.43 (phục vụ) = 4.60h
#  Quận 1: Tổng quãng đường=24.99km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.50 (nạp lại) + 3.92 (phục vụ) = 4.92h
#  Quận 0: Tổng quãng đường=21.09km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.46 (phục vụ) = 4.63h
#  Quận 1: Tổng quãng đường=24.58km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.89 (phục vụ) = 4.88h
#  Quận 0: Tổng quãng đường=23.07km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.72 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=22.99km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.63 (phục vụ) = 4.59h
#  Quận 0: Tổng quãng đường=21.46km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.50 (phục vụ) = 4.68h
#  Quận 1: Tổng quãng đường=24.72km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.85 (phục vụ) = 4.84h
#  Quận 0: Tổng quãng đường=23.00km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.73 (phục vụ) = 4.94h
#  Quận 1: Tổng quãng đường=22.20km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.62 (phục vụ) = 4.56h
#  Quận 0: Tổng quãng đường=22.89km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.73 (phục vụ) = 4.94h
#  Quận 1: Tổng quãng đường=23.23km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.62 (phục vụ) = 4.58h
#  Quận 0: Tổng quãng đường=20.69km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.75 (nạp lại) + 3.43 (phục vụ) = 4.59h
#  Quận 1: Tổng quãng đường=24.70km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.92 (phục vụ) = 4.91h
#  Quận 0: Tổng quãng đường=23.07km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.72 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=22.99km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.63 (phục vụ) = 4.59h
#  Quận 0: Tổng quãng đường=22.76km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=23.46km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.54h
#  Quận 0: Tổng quãng đường=22.89km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.73 (phục vụ) = 4.94h
#  Quận 1: Tổng quãng đường=23.23km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.62 (phục vụ) = 4.58h
#  Quận 0: Tổng quãng đường=23.13km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.72 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=22.78km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.63 (phục vụ) = 4.59h
#  Quận 0: Tổng quãng đường=23.19km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=22.85km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.53h
#  Quận 0: Tổng quãng đường=22.37km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=23.08km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.53h
#  Quận 0: Tổng quãng đường=23.20km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.73 (phục vụ) = 4.94h
#  Quận 1: Tổng quãng đường=22.07km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.62 (phục vụ) = 4.56h
#  Quận 0: Tổng quãng đường=21.03km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.43 (phục vụ) = 4.60h
#  Quận 1: Tổng quãng đường=25.00km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.50 (nạp lại) + 3.92 (phục vụ) = 4.92h
#  Quận 0: Tổng quãng đường=22.78km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.74 (phục vụ) = 4.95h
#  Quận 1: Tổng quãng đường=23.28km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.58h
#  Quận 0: Tổng quãng đường=20.69km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.75 (nạp lại) + 3.43 (phục vụ) = 4.59h
#  Quận 1: Tổng quãng đường=24.93km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.50 (nạp lại) + 3.92 (phục vụ) = 4.92h
#  Quận 0: Tổng quãng đường=20.93km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.49 (phục vụ) = 4.66h
#  Quận 1: Tổng quãng đường=23.66km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.86 (phục vụ) = 4.83h
#  Quận 0: Tổng quãng đường=21.90km, Thời gian di chuyển=0.44h
#  Quận 0: 0.44 (di chuyển) + 0.75 (nạp lại) + 3.60 (phục vụ) = 4.79h
#  Quận 1: Tổng quãng đường=22.65km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.75 (phục vụ) = 4.70h
#  Quận 0: Tổng quãng đường=23.31km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.74 (phục vụ) = 4.96h
#  Quận 1: Tổng quãng đường=21.41km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.54h
#  Quận 0: Tổng quãng đường=22.39km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=22.01km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.51h
#  Quận 0: Tổng quãng đường=23.31km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.74 (phục vụ) = 4.96h
#  Quận 1: Tổng quãng đường=21.41km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.61 (phục vụ) = 4.54h
#  Quận 0: Tổng quãng đường=19.46km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.43 (phục vụ) = 4.32h
#  Quận 1: Tổng quãng đường=24.54km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.92 (phục vụ) = 4.91h
#  Quận 0: Tổng quãng đường=19.79km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.42 (phục vụ) = 4.32h
#  Quận 1: Tổng quãng đường=24.15km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.93 (phục vụ) = 4.91h
#  Quận 0: Tổng quãng đường=20.76km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.43 (phục vụ) = 4.60h
#  Quận 1: Tổng quãng đường=23.97km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.92 (phục vụ) = 4.90h
#  Quận 0: Tổng quãng đường=21.53km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.42 (phục vụ) = 4.60h
#  Quận 1: Tổng quãng đường=23.43km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.93 (phục vụ) = 4.90h
#  Quận 0: Tổng quãng đường=19.79km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.42 (phục vụ) = 4.32h
#  Quận 1: Tổng quãng đường=24.15km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.93 (phục vụ) = 4.91h
#  Quận 0: Tổng quãng đường=20.93km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.49 (phục vụ) = 4.66h
#  Quận 1: Tổng quãng đường=23.66km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.86 (phục vụ) = 4.83h
#  Quận 0: Tổng quãng đường=21.53km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.42 (phục vụ) = 4.60h
#  Quận 1: Tổng quãng đường=23.43km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.93 (phục vụ) = 4.90h
#  Quận 0: Tổng quãng đường=21.62km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.49 (phục vụ) = 4.67h
#  Quận 1: Tổng quãng đường=23.86km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.86 (phục vụ) = 4.84h
#  Quận 0: Tổng quãng đường=21.53km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.42 (phục vụ) = 4.60h
#  Quận 1: Tổng quãng đường=23.43km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.93 (phục vụ) = 4.90h
#  Quận 0: Tổng quãng đường=21.59km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.46 (phục vụ) = 4.64h
#  Quận 1: Tổng quãng đường=23.93km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.89 (phục vụ) = 4.87h
#  Quận 0: Tổng quãng đường=23.29km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.72 (phục vụ) = 4.94h
#  Quận 1: Tổng quãng đường=21.20km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.63 (phục vụ) = 4.55h
#  Quận 0: Tổng quãng đường=23.29km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.72 (phục vụ) = 4.94h
#  Quận 1: Tổng quãng đường=21.20km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.63 (phục vụ) = 4.55h
#  Quận 0: Tổng quãng đường=23.09km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.72 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=21.34km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.63 (phục vụ) = 4.56h
#  Quận 0: Tổng quãng đường=21.15km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.45 (phục vụ) = 4.62h
#  Quận 1: Tổng quãng đường=23.69km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.90 (phục vụ) = 4.87h
#  Quận 0: Tổng quãng đường=21.15km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.45 (phục vụ) = 4.62h
#  Quận 1: Tổng quãng đường=23.69km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.90 (phục vụ) = 4.87h
#  Quận 0: Tổng quãng đường=21.15km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.48 (phục vụ) = 4.65h
#  Quận 1: Tổng quãng đường=23.69km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.84h
#  Quận 0: Tổng quãng đường=20.76km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.42 (phục vụ) = 4.59h
#  Quận 1: Tổng quãng đường=24.03km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.93 (phục vụ) = 4.91h
#  Quận 0: Tổng quãng đường=21.62km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.49 (phục vụ) = 4.67h
#  Quận 1: Tổng quãng đường=23.86km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.86 (phục vụ) = 4.84h
#  Quận 0: Tổng quãng đường=22.75km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.72 (phục vụ) = 4.93h
#  Quận 1: Tổng quãng đường=22.51km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.63 (phục vụ) = 4.58h
#  Quận 0: Tổng quãng đường=19.36km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.42 (phục vụ) = 4.31h
#  Quận 1: Tổng quãng đường=23.94km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.93 (phục vụ) = 4.91h
#  Quận 0: Tổng quãng đường=21.27km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.42 (phục vụ) = 4.60h
#  Quận 1: Tổng quãng đường=24.13km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.93 (phục vụ) = 4.91h
#  Quận 0: Tổng quãng đường=20.93km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.49 (phục vụ) = 4.66h
#  Quận 1: Tổng quãng đường=23.66km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.86 (phục vụ) = 4.83h
#  Quận 0: Tổng quãng đường=22.39km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=22.01km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.51h
#  Quận 0: Tổng quãng đường=19.36km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.42 (phục vụ) = 4.31h
#  Quận 1: Tổng quãng đường=23.94km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.93 (phục vụ) = 4.91h
#  Quận 0: Tổng quãng đường=19.75km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.38h
#  Quận 1: Tổng quãng đường=24.00km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.85h
#  Quận 0: Tổng quãng đường=20.82km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.42 (phục vụ) = 4.59h
#  Quận 1: Tổng quãng đường=23.86km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.93 (phục vụ) = 4.91h
#  Quận 0: Tổng quãng đường=23.29km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.72 (phục vụ) = 4.94h
#  Quận 1: Tổng quãng đường=21.20km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.63 (phục vụ) = 4.55h
#  Quận 0: Tổng quãng đường=22.68km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.91h
#  Quận 1: Tổng quãng đường=21.24km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.56h
#  Quận 0: Tổng quãng đường=21.57km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.54 (phục vụ) = 4.72h
#  Quận 1: Tổng quãng đường=22.52km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.81 (phục vụ) = 4.76h
#  Quận 0: Tổng quãng đường=19.66km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.38 (phục vụ) = 4.27h
#  Quận 1: Tổng quãng đường=23.88km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.97 (phục vụ) = 4.95h
#  Quận 0: Tổng quãng đường=18.93km, Thời gian di chuyển=0.38h
#  Quận 0: 0.38 (di chuyển) + 0.50 (nạp lại) + 3.36 (phục vụ) = 4.24h
#  Quận 1: Tổng quãng đường=23.91km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.99 (phục vụ) = 4.97h
#  Quận 0: Tổng quãng đường=19.84km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.43 (phục vụ) = 4.33h
#  Quận 1: Tổng quãng đường=24.69km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.92 (phục vụ) = 5.16h
#  Quận 0: Tổng quãng đường=19.52km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.36 (phục vụ) = 4.25h
#  Quận 1: Tổng quãng đường=24.01km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.99 (phục vụ) = 4.97h
#  Quận 0: Tổng quãng đường=22.75km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.66 (phục vụ) = 4.86h
#  Quận 1: Tổng quãng đường=21.23km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.69 (phục vụ) = 4.61h
#  Quận 0: Tổng quãng đường=18.98km, Thời gian di chuyển=0.38h
#  Quận 0: 0.38 (di chuyển) + 0.50 (nạp lại) + 3.36 (phục vụ) = 4.24h
#  Quận 1: Tổng quãng đường=24.75km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.99 (phục vụ) = 5.23h
#  Quận 0: Tổng quãng đường=18.93km, Thời gian di chuyển=0.38h
#  Quận 0: 0.38 (di chuyển) + 0.50 (nạp lại) + 3.36 (phục vụ) = 4.24h
#  Quận 1: Tổng quãng đường=23.91km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.99 (phục vụ) = 4.97h
#  Quận 0: Tổng quãng đường=22.92km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.69 (phục vụ) = 4.90h
#  Quận 1: Tổng quãng đường=21.58km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.66 (phục vụ) = 4.59h
#  Quận 0: Tổng quãng đường=20.76km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.43 (phục vụ) = 4.60h
#  Quận 1: Tổng quãng đường=23.97km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.92 (phục vụ) = 4.90h
#  Quận 0: Tổng quãng đường=21.91km, Thời gian di chuyển=0.44h
#  Quận 0: 0.44 (di chuyển) + 0.75 (nạp lại) + 3.66 (phục vụ) = 4.85h
#  Quận 1: Tổng quãng đường=21.79km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.69 (phục vụ) = 4.63h
#  Quận 0: Tổng quãng đường=19.32km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.37h
#  Quận 1: Tổng quãng đường=23.17km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.83h
#  Quận 0: Tổng quãng đường=19.46km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.44h
#  Quận 1: Tổng quãng đường=22.79km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.80 (phục vụ) = 4.76h
#  Quận 0: Tổng quãng đường=19.46km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.44h
#  Quận 1: Tổng quãng đường=22.79km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.80 (phục vụ) = 4.76h
#  Quận 0: Tổng quãng đường=20.20km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.45h
#  Quận 1: Tổng quãng đường=23.01km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.80 (phục vụ) = 4.76h
#  Quận 0: Tổng quãng đường=23.09km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=20.48km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.48h
#  Quận 0: Tổng quãng đường=21.57km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.54 (phục vụ) = 4.72h
#  Quận 1: Tổng quãng đường=22.52km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.81 (phục vụ) = 4.76h
#  Quận 0: Tổng quãng đường=19.87km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.38h
#  Quận 1: Tổng quãng đường=23.28km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.84h
#  Quận 0: Tổng quãng đường=19.78km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.38h
#  Quận 1: Tổng quãng đường=24.30km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.87 (phục vụ) = 5.11h
#  Quận 0: Tổng quãng đường=23.09km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=20.48km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.48h
#  Quận 0: Tổng quãng đường=22.51km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.83 (phục vụ) = 5.03h
#  Quận 1: Tổng quãng đường=21.34km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.52 (phục vụ) = 4.45h
#  Quận 0: Tổng quãng đường=21.60km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.52 (phục vụ) = 4.70h
#  Quận 1: Tổng quãng đường=23.08km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.83 (phục vụ) = 4.79h
#  Quận 0: Tổng quãng đường=23.24km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.81 (phục vụ) = 5.02h
#  Quận 1: Tổng quãng đường=20.84km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.54 (phục vụ) = 4.46h
#  Quận 0: Tổng quãng đường=19.46km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.44h
#  Quận 1: Tổng quãng đường=22.79km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.80 (phục vụ) = 4.76h
#  Quận 0: Tổng quãng đường=19.72km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.51 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=22.84km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.84 (phục vụ) = 4.80h
#  Quận 0: Tổng quãng đường=23.02km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.83 (phục vụ) = 5.04h
#  Quận 1: Tổng quãng đường=20.49km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.52 (phục vụ) = 4.43h
#  Quận 0: Tổng quãng đường=19.74km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.39h
#  Quận 1: Tổng quãng đường=22.66km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.85 (phục vụ) = 4.80h
#  Quận 0: Tổng quãng đường=22.77km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=20.98km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.50h
#  Quận 0: Tổng quãng đường=22.77km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=20.98km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.50h
#  Quận 0: Tổng quãng đường=19.76km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.38h
#  Quận 1: Tổng quãng đường=23.35km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.84h
#  Quận 0: Tổng quãng đường=23.09km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 4.99h
#  Quận 1: Tổng quãng đường=20.48km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.48h
#  Quận 0: Tổng quãng đường=22.77km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=20.98km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.50h
#  Quận 0: Tổng quãng đường=20.20km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.45h
#  Quận 1: Tổng quãng đường=23.01km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.80 (phục vụ) = 4.76h
#  Quận 0: Tổng quãng đường=23.31km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.80 (phục vụ) = 5.02h
#  Quận 1: Tổng quãng đường=20.58km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.46h
#  Quận 0: Tổng quãng đường=22.77km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=20.98km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.50h
#  Quận 0: Tổng quãng đường=22.77km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=20.98km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.50h
#  Quận 0: Tổng quãng đường=23.28km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 5.00h
#  Quận 1: Tổng quãng đường=20.34km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.48h
#  Quận 0: Tổng quãng đường=19.36km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.37h
#  Quận 1: Tổng quãng đường=24.12km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.87 (phục vụ) = 5.10h
#  Quận 0: Tổng quãng đường=22.58km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=20.74km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.48h
#  Quận 0: Tổng quãng đường=19.87km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.38h
#  Quận 1: Tổng quãng đường=23.28km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.84h
#  Quận 0: Tổng quãng đường=19.74km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.39h
#  Quận 1: Tổng quãng đường=22.66km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.85 (phục vụ) = 4.80h
#  Quận 0: Tổng quãng đường=21.60km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.52 (phục vụ) = 4.70h
#  Quận 1: Tổng quãng đường=23.08km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.83 (phục vụ) = 4.79h
#  Quận 0: Tổng quãng đường=20.09km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.38h
#  Quận 1: Tổng quãng đường=22.58km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.82h
#  Quận 0: Tổng quãng đường=19.72km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.54 (phục vụ) = 4.43h
#  Quận 1: Tổng quãng đường=22.84km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.81 (phục vụ) = 4.77h
#  Quận 0: Tổng quãng đường=19.78km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.38h
#  Quận 1: Tổng quãng đường=24.30km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.87 (phục vụ) = 5.11h
#  Quận 0: Tổng quãng đường=21.08km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.55 (phục vụ) = 4.72h
#  Quận 1: Tổng quãng đường=23.24km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.80 (phục vụ) = 4.76h
#  Quận 0: Tổng quãng đường=20.09km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.38h
#  Quận 1: Tổng quãng đường=22.58km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.82h
#  Quận 0: Tổng quãng đường=19.87km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.53 (phục vụ) = 4.43h
#  Quận 1: Tổng quãng đường=22.93km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.82 (phục vụ) = 4.78h
#  Quận 0: Tổng quãng đường=22.58km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=20.74km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.48h
#  Quận 0: Tổng quãng đường=19.46km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.44h
#  Quận 1: Tổng quãng đường=22.79km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.80 (phục vụ) = 4.76h
#  Quận 0: Tổng quãng đường=21.60km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.52 (phục vụ) = 4.70h
#  Quận 1: Tổng quãng đường=23.08km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.83 (phục vụ) = 4.79h
#  Quận 0: Tổng quãng đường=19.72km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.51 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=22.84km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.84 (phục vụ) = 4.80h
#  Quận 0: Tổng quãng đường=19.78km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.38h
#  Quận 1: Tổng quãng đường=24.30km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.87 (phục vụ) = 5.11h
#  Quận 0: Tổng quãng đường=21.60km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.75 (nạp lại) + 3.52 (phục vụ) = 4.70h
#  Quận 1: Tổng quãng đường=23.08km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.83 (phục vụ) = 4.79h
#  Quận 0: Tổng quãng đường=20.09km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.38h
#  Quận 1: Tổng quãng đường=22.58km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.82h
#  Quận 0: Tổng quãng đường=22.75km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 4.98h
#  Quận 1: Tổng quãng đường=21.61km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.50h
#  Quận 0: Tổng quãng đường=23.28km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.78 (phục vụ) = 5.00h
#  Quận 1: Tổng quãng đường=20.34km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.48h
#  Quận 0: Tổng quãng đường=19.72km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.51 (phục vụ) = 4.40h
#  Quận 1: Tổng quãng đường=22.84km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.84 (phục vụ) = 4.80h
#  Quận 0: Tổng quãng đường=19.36km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.37h
#  Quận 1: Tổng quãng đường=23.01km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.83h
#  Quận 0: Tổng quãng đường=23.24km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.81 (phục vụ) = 5.02h
#  Quận 1: Tổng quãng đường=20.84km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.54 (phục vụ) = 4.46h
#  Quận 0: Tổng quãng đường=21.08km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.55 (phục vụ) = 4.72h
#  Quận 1: Tổng quãng đường=23.24km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.80 (phục vụ) = 4.76h
#  Quận 0: Tổng quãng đường=21.08km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.75 (nạp lại) + 3.55 (phục vụ) = 4.72h
#  Quận 1: Tổng quãng đường=23.24km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.80 (phục vụ) = 4.76h
#  Quận 0: Tổng quãng đường=23.02km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.83 (phục vụ) = 5.04h
#  Quận 1: Tổng quãng đường=20.49km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.52 (phục vụ) = 4.43h
#  Quận 0: Tổng quãng đường=22.40km, Thời gian di chuyển=0.45h
#  Quận 0: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.84 (phục vụ) = 5.04h
#  Quận 1: Tổng quãng đường=21.14km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.51 (phục vụ) = 4.43h
#  Quận 0: Tổng quãng đường=23.31km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.80 (phục vụ) = 5.02h
#  Quận 1: Tổng quãng đường=20.58km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.46h
#  Quận 0: Tổng quãng đường=19.76km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.38h
#  Quận 1: Tổng quãng đường=23.35km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.84h
#  Quận 0: Tổng quãng đường=20.20km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.45h
#  Quận 1: Tổng quãng đường=23.01km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.80 (phục vụ) = 4.76h
#  Quận 0: Tổng quãng đường=23.24km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.81 (phục vụ) = 5.02h
#  Quận 1: Tổng quãng đường=20.84km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.54 (phục vụ) = 4.46h
#  Quận 0: Tổng quãng đường=19.32km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.37h
#  Quận 1: Tổng quãng đường=23.17km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.83h
#  Quận 0: Tổng quãng đường=19.72km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.54 (phục vụ) = 4.43h
#  Quận 1: Tổng quãng đường=22.84km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.81 (phục vụ) = 4.77h
#  Quận 0: Tổng quãng đường=23.31km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.80 (phục vụ) = 5.02h
#  Quận 1: Tổng quãng đường=20.58km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.46h
#  Quận 0: Tổng quãng đường=23.26km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.63 (phục vụ) = 4.85h
#  Quận 1: Tổng quãng đường=22.29km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.72 (phục vụ) = 4.67h
#  Quận 0: Tổng quãng đường=20.63km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.69 (phục vụ) = 4.60h
#  Quận 1: Tổng quãng đường=22.10km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.66 (phục vụ) = 4.60h
#  Quận 0: Tổng quãng đường=21.91km, Thời gian di chuyển=0.44h
#  Quận 0: 0.44 (di chuyển) + 0.75 (nạp lại) + 3.66 (phục vụ) = 4.85h
#  Quận 1: Tổng quãng đường=21.79km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.69 (phục vụ) = 4.63h
# VNS_2 Iter 0, k=1: New best = 0.0834
#  Quận 0: Tổng quãng đường=19.36km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.37h
#  Quận 1: Tổng quãng đường=23.01km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.83h
#  Quận 0: Tổng quãng đường=20.30km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.50h
#  Quận 1: Tổng quãng đường=22.19km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.76 (phục vụ) = 4.70h
#  Quận 0: Tổng quãng đường=19.36km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.37h
#  Quận 1: Tổng quãng đường=23.01km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.83h
#  Quận 0: Tổng quãng đường=19.68km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.30h
#  Quận 1: Tổng quãng đường=24.69km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.18h
#  Quận 0: Tổng quãng đường=19.29km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.37h
#  Quận 1: Tổng quãng đường=24.28km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.87 (phục vụ) = 5.11h
#  Quận 0: Tổng quãng đường=19.93km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.31h
#  Quận 1: Tổng quãng đường=24.01km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.17h
#  Quận 0: Tổng quãng đường=19.36km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.37h
#  Quận 1: Tổng quãng đường=23.01km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.83h
#  Quận 0: Tổng quãng đường=19.36km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.37h
#  Quận 1: Tổng quãng đường=23.01km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.87 (phục vụ) = 4.83h
#  Quận 0: Tổng quãng đường=22.90km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.71 (phục vụ) = 4.92h
#  Quận 1: Tổng quãng đường=20.87km, Thời gian di chuyển=0.42h
#  Quận 1: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.56h
#  Quận 0: Tổng quãng đường=19.68km, Thời gian di chuyển=0.39h
#  Quận 0: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.41 (phục vụ) = 4.30h
#  Quận 1: Tổng quãng đường=24.69km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.94 (phục vụ) = 5.18h
#  Quận 0: Tổng quãng đường=21.73km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.71 (phục vụ) = 4.64h
#  Quận 1: Tổng quãng đường=20.73km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.55h
#  Quận 0: Tổng quãng đường=21.02km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.51h
#  Quận 1: Tổng quãng đường=23.11km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.76 (phục vụ) = 4.97h
#  Quận 0: Tổng quãng đường=24.27km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.83 (phục vụ) = 5.07h
#  Quận 1: Tổng quãng đường=19.40km, Thời gian di chuyển=0.39h
#  Quận 1: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.52 (phục vụ) = 4.41h
#  Quận 0: Tổng quãng đường=20.92km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.60 (phục vụ) = 4.52h
#  Quận 1: Tổng quãng đường=22.16km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.75 (phục vụ) = 4.69h
#  Quận 0: Tổng quãng đường=23.93km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.83 (phục vụ) = 5.06h
#  Quận 1: Tổng quãng đường=20.54km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.52 (phục vụ) = 4.43h
#  Quận 0: Tổng quãng đường=20.98km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.47h
#  Quận 1: Tổng quãng đường=22.66km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.75 (nạp lại) + 3.80 (phục vụ) = 5.00h
#  Quận 0: Tổng quãng đường=24.51km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.85 (phục vụ) = 5.09h
#  Quận 1: Tổng quãng đường=19.50km, Thời gian di chuyển=0.39h
#  Quận 1: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.39h
#  Quận 0: Tổng quãng đường=21.38km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.52h
#  Quận 1: Tổng quãng đường=21.47km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.76 (phục vụ) = 4.69h
#  Quận 0: Tổng quãng đường=20.96km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.51h
#  Quận 1: Tổng quãng đường=22.83km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.76 (phục vụ) = 4.97h
#  Quận 0: Tổng quãng đường=21.02km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.51h
#  Quận 1: Tổng quãng đường=23.11km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.76 (phục vụ) = 4.97h
#  Quận 0: Tổng quãng đường=21.16km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.50h
#  Quận 1: Tổng quãng đường=22.91km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 4.98h
#  Quận 0: Tổng quãng đường=24.51km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.85 (phục vụ) = 5.09h
#  Quận 1: Tổng quãng đường=19.50km, Thời gian di chuyển=0.39h
#  Quận 1: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.39h
#  Quận 0: Tổng quãng đường=21.12km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.53 (phục vụ) = 4.45h
#  Quận 1: Tổng quãng đường=23.22km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.82 (phục vụ) = 5.03h
#  Quận 0: Tổng quãng đường=24.14km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.89 (phục vụ) = 5.12h
#  Quận 1: Tổng quãng đường=19.50km, Thời gian di chuyển=0.39h
#  Quận 1: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.46 (phục vụ) = 4.35h
#  Quận 0: Tổng quãng đường=23.93km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.83 (phục vụ) = 5.06h
#  Quận 1: Tổng quãng đường=20.54km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.52 (phục vụ) = 4.43h
#  Quận 0: Tổng quãng đường=21.43km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.50h
#  Quận 1: Tổng quãng đường=22.02km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.78 (phục vụ) = 4.72h
#  Quận 0: Tổng quãng đường=24.21km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.11h
#  Quận 1: Tổng quãng đường=19.41km, Thời gian di chuyển=0.39h
#  Quận 1: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.36h
#  Quận 0: Tổng quãng đường=21.02km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.51h
#  Quận 1: Tổng quãng đường=23.11km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.76 (phục vụ) = 4.97h
#  Quận 0: Tổng quãng đường=20.96km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.51h
#  Quận 1: Tổng quãng đường=22.83km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.76 (phục vụ) = 4.97h
#  Quận 0: Tổng quãng đường=20.92km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.60 (phục vụ) = 4.52h
#  Quận 1: Tổng quãng đường=22.16km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.75 (phục vụ) = 4.69h
#  Quận 0: Tổng quãng đường=24.43km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.86 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=19.76km, Thời gian di chuyển=0.40h
#  Quận 1: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.49 (phục vụ) = 4.39h
#  Quận 0: Tổng quãng đường=21.35km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.53 (phục vụ) = 4.46h
#  Quận 1: Tổng quãng đường=21.52km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.82 (phục vụ) = 4.75h
#  Quận 0: Tổng quãng đường=24.21km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.11h
#  Quận 1: Tổng quãng đường=19.41km, Thời gian di chuyển=0.39h
#  Quận 1: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.36h
#  Quận 0: Tổng quãng đường=20.92km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.60 (phục vụ) = 4.52h
#  Quận 1: Tổng quãng đường=22.16km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.75 (phục vụ) = 4.69h
#  Quận 0: Tổng quãng đường=21.02km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.53 (phục vụ) = 4.45h
#  Quận 1: Tổng quãng đường=23.29km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.82 (phục vụ) = 5.04h
#  Quận 0: Tổng quãng đường=20.92km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.60 (phục vụ) = 4.52h
#  Quận 1: Tổng quãng đường=22.16km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.75 (phục vụ) = 4.69h
#  Quận 0: Tổng quãng đường=23.68km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=20.27km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.38h
#  Quận 0: Tổng quãng đường=24.51km, Thời gian di chuyển=0.49h
#  Quận 0: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.85 (phục vụ) = 5.09h
#  Quận 1: Tổng quãng đường=19.50km, Thời gian di chuyển=0.39h
#  Quận 1: 0.39 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.39h
#  Quận 0: Tổng quãng đường=20.96km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.56 (phục vụ) = 4.48h
#  Quận 1: Tổng quãng đường=22.83km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.79 (phục vụ) = 5.00h
#  Quận 0: Tổng quãng đường=23.99km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.11h
#  Quận 1: Tổng quãng đường=20.37km, Thời gian di chuyển=0.41h
#  Quận 1: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.38h
#  Quận 0: Tổng quãng đường=21.43km, Thời gian di chuyển=0.43h
#  Quận 0: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.50h
#  Quận 1: Tổng quãng đường=22.02km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.78 (phục vụ) = 4.72h
# ...
#  Quận 1: 0.49 (di chuyển) + 0.50 (nạp lại) + 3.75 (phục vụ) = 4.74h
#  Quận 0: Tổng quãng đường=20.64km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.50h
#  Quận 1: Tổng quãng đường=24.95km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.76 (phục vụ) = 5.01h
#  Quận 0: Tổng quãng đường=20.25km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.50h
#  Quận 1: Tổng quãng đường=24.92km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.76 (phục vụ) = 5.01h
#  Quận 0: Tổng quãng đường=23.68km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.89 (phục vụ) = 5.11h
#  Quận 1: Tổng quãng đường=21.54km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.46 (phục vụ) = 4.39h
#  Quận 0: Tổng quãng đường=23.93km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.83 (phục vụ) = 5.06h
#  Quận 1: Tổng quãng đường=22.22km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.52 (phục vụ) = 4.46h
#  Quận 0: Tổng quãng đường=20.35km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.53 (phục vụ) = 4.44h
#  Quận 1: Tổng quãng đường=25.28km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.82 (phục vụ) = 5.08h
#  Quận 0: Tổng quãng đường=20.03km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.48h
#  Quận 1: Tổng quãng đường=24.03km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 5.00h
#  Quận 0: Tổng quãng đường=20.25km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.50h
#  Quận 1: Tổng quãng đường=24.92km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.76 (phục vụ) = 5.01h
#  Quận 0: Tổng quãng đường=23.98km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.85 (phục vụ) = 5.08h
#  Quận 1: Tổng quãng đường=22.16km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.44h
#  Quận 0: Tổng quãng đường=20.30km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.46h
#  Quận 1: Tổng quãng đường=24.73km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.80 (phục vụ) = 5.04h
#  Quận 0: Tổng quãng đường=20.25km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.50h
#  Quận 1: Tổng quãng đường=24.92km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.76 (phục vụ) = 5.01h
#  Quận 0: Tổng quãng đường=20.92km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.60 (phục vụ) = 4.52h
#  Quận 1: Tổng quãng đường=25.06km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.75 (phục vụ) = 5.00h
#  Quận 0: Tổng quãng đường=23.03km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.09h
#  Quận 1: Tổng quãng đường=22.53km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.42h
#  Quận 0: Tổng quãng đường=23.83km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.82 (phục vụ) = 5.05h
#  Quận 1: Tổng quãng đường=22.32km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.53 (phục vụ) = 4.48h
#  Quận 0: Tổng quãng đường=23.50km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.83 (phục vụ) = 5.05h
#  Quận 1: Tổng quãng đường=21.61km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.52 (phục vụ) = 4.45h
#  Quận 0: Tổng quãng đường=23.98km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.85 (phục vụ) = 5.08h
#  Quận 1: Tổng quãng đường=22.16km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.44h
#  Quận 0: Tổng quãng đường=20.74km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.53 (phục vụ) = 4.44h
#  Quận 1: Tổng quãng đường=23.60km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.82 (phục vụ) = 4.79h
#  Quận 0: Tổng quãng đường=20.21km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.53 (phục vụ) = 4.43h
#  Quận 1: Tổng quãng đường=25.10km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.82 (phục vụ) = 5.07h
#  Quận 0: Tổng quãng đường=23.95km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.11h
#  Quận 1: Tổng quãng đường=22.12km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.41h
#  Quận 0: Tổng quãng đường=23.89km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.87 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=21.32km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.41h
#  Quận 0: Tổng quãng đường=23.39km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=22.71km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.42h
#  Quận 0: Tổng quãng đường=20.30km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.46h
#  Quận 1: Tổng quãng đường=24.73km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.80 (phục vụ) = 5.04h
#  Quận 0: Tổng quãng đường=20.92km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.60 (phục vụ) = 4.52h
#  Quận 1: Tổng quãng đường=25.06km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.75 (phục vụ) = 5.00h
#  Quận 0: Tổng quãng đường=23.86km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.11h
#  Quận 1: Tổng quãng đường=22.32km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.42h
#  Quận 0: Tổng quãng đường=20.48km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.46h
#  Quận 1: Tổng quãng đường=25.21km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.80 (phục vụ) = 5.05h
#  Quận 0: Tổng quãng đường=23.42km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=21.62km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.40h
#  Quận 0: Tổng quãng đường=23.89km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.87 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=21.32km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.41h
#  Quận 0: Tổng quãng đường=23.92km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.87 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=22.23km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.42h
#  Quận 0: Tổng quãng đường=23.42km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=21.62km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.40h
#  Quận 0: Tổng quãng đường=20.03km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.48h
#  Quận 1: Tổng quãng đường=24.03km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 5.00h
#  Quận 0: Tổng quãng đường=23.92km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.87 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=22.23km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.48 (phục vụ) = 4.42h
#  Quận 0: Tổng quãng đường=20.21km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.53 (phục vụ) = 4.43h
#  Quận 1: Tổng quãng đường=25.10km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.82 (phục vụ) = 5.07h
#  Quận 0: Tổng quãng đường=23.86km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.11h
#  Quận 1: Tổng quãng đường=22.32km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.42h
#  Quận 0: Tổng quãng đường=23.98km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.85 (phục vụ) = 5.08h
#  Quận 1: Tổng quãng đường=22.16km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.50 (phục vụ) = 4.44h
#  Quận 0: Tổng quãng đường=23.86km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.11h
#  Quận 1: Tổng quãng đường=22.32km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.42h
#  Quận 0: Tổng quãng đường=20.30km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.55 (phục vụ) = 4.46h
#  Quận 1: Tổng quãng đường=24.73km, Thời gian di chuyển=0.49h
#  Quận 1: 0.49 (di chuyển) + 0.75 (nạp lại) + 3.80 (phục vụ) = 5.04h
#  Quận 0: Tổng quãng đường=23.87km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.82 (phục vụ) = 5.05h
#  Quận 1: Tổng quãng đường=22.23km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.53 (phục vụ) = 4.47h
#  Quận 0: Tổng quãng đường=20.78km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.51h
#  Quận 1: Tổng quãng đường=23.66km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.76 (phục vụ) = 4.73h
#  Quận 0: Tổng quãng đường=23.68km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.89 (phục vụ) = 5.11h
#  Quận 1: Tổng quãng đường=21.54km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.46 (phục vụ) = 4.39h
#  Quận 0: Tổng quãng đường=23.42km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=21.62km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.40h
#  Quận 0: Tổng quãng đường=20.77km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.50h
#  Quận 1: Tổng quãng đường=25.00km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 5.02h
#  Quận 0: Tổng quãng đường=20.78km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.59 (phục vụ) = 4.51h
#  Quận 1: Tổng quãng đường=23.66km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.76 (phục vụ) = 4.73h
#  Quận 0: Tổng quãng đường=22.85km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.89 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=22.15km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.46 (phục vụ) = 4.40h
#  Quận 0: Tổng quãng đường=23.03km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.09h
#  Quận 1: Tổng quãng đường=22.53km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.42h
#  Quận 0: Tổng quãng đường=22.85km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.89 (phục vụ) = 5.10h
#  Quận 1: Tổng quãng đường=22.15km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.46 (phục vụ) = 4.40h
#  Quận 0: Tổng quãng đường=23.50km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.83 (phục vụ) = 5.05h
#  Quận 1: Tổng quãng đường=21.61km, Thời gian di chuyển=0.43h
#  Quận 1: 0.43 (di chuyển) + 0.50 (nạp lại) + 3.52 (phục vụ) = 4.45h
#  Quận 0: Tổng quãng đường=23.74km, Thời gian di chuyển=0.47h
#  Quận 0: 0.47 (di chuyển) + 0.75 (nạp lại) + 3.82 (phục vụ) = 5.04h
#  Quận 1: Tổng quãng đường=22.47km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.53 (phục vụ) = 4.48h
#  Quận 0: Tổng quãng đường=23.93km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.83 (phục vụ) = 5.06h
#  Quận 1: Tổng quãng đường=22.22km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.52 (phục vụ) = 4.46h
#  Quận 0: Tổng quãng đường=23.86km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.11h
#  Quận 1: Tổng quãng đường=22.32km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.42h
#  Quận 0: Tổng quãng đường=23.88km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.89 (phục vụ) = 5.12h
#  Quận 1: Tổng quãng đường=22.16km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.46 (phục vụ) = 4.40h
#  Quận 0: Tổng quãng đường=20.77km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.50h
#  Quận 1: Tổng quãng đường=25.00km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 5.02h
#  Quận 0: Tổng quãng đường=23.03km, Thời gian di chuyển=0.46h
#  Quận 0: 0.46 (di chuyển) + 0.75 (nạp lại) + 3.88 (phục vụ) = 5.09h
#  Quận 1: Tổng quãng đường=22.53km, Thời gian di chuyển=0.45h
#  Quận 1: 0.45 (di chuyển) + 0.50 (nạp lại) + 3.47 (phục vụ) = 4.42h
#  Quận 0: Tổng quãng đường=23.88km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.89 (phục vụ) = 5.12h
#  Quận 1: Tổng quãng đường=22.16km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.46 (phục vụ) = 4.40h
#  Quận 0: Tổng quãng đường=20.74km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.53 (phục vụ) = 4.44h
#  Quận 1: Tổng quãng đường=23.60km, Thời gian di chuyển=0.47h
#  Quận 1: 0.47 (di chuyển) + 0.50 (nạp lại) + 3.82 (phục vụ) = 4.79h
#  Quận 0: Tổng quãng đường=20.35km, Thời gian di chuyển=0.41h
#  Quận 0: 0.41 (di chuyển) + 0.50 (nạp lại) + 3.53 (phục vụ) = 4.44h
#  Quận 1: Tổng quãng đường=25.28km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.82 (phục vụ) = 5.08h
#  Quận 0: Tổng quãng đường=20.24km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.56 (phục vụ) = 4.46h
#  Quận 1: Tổng quãng đường=25.27km, Thời gian di chuyển=0.51h
#  Quận 1: 0.51 (di chuyển) + 0.75 (nạp lại) + 3.79 (phục vụ) = 5.05h
#  Quận 0: Tổng quãng đường=20.82km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.57 (phục vụ) = 4.49h
#  Quận 1: Tổng quãng đường=24.22km, Thời gian di chuyển=0.48h
#  Quận 1: 0.48 (di chuyển) + 0.50 (nạp lại) + 3.78 (phục vụ) = 4.76h
#  Quận 0: Tổng quãng đường=20.77km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.58 (phục vụ) = 4.50h
#  Quận 1: Tổng quãng đường=25.00km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.77 (phục vụ) = 5.02h
#  Quận 0: Tổng quãng đường=20.21km, Thời gian di chuyển=0.40h
#  Quận 0: 0.40 (di chuyển) + 0.50 (nạp lại) + 3.53 (phục vụ) = 4.43h
#  Quận 1: Tổng quãng đường=25.10km, Thời gian di chuyển=0.50h
#  Quận 1: 0.50 (di chuyển) + 0.75 (nạp lại) + 3.82 (phục vụ) = 5.07h
#  Quận 0: Tổng quãng đường=23.93km, Thời gian di chuyển=0.48h
#  Quận 0: 0.48 (di chuyển) + 0.75 (nạp lại) + 3.83 (phục vụ) = 5.06h
#  Quận 1: Tổng quãng đường=22.22km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.52 (phục vụ) = 4.46h
#  Quận 0: Tổng quãng đường=21.17km, Thời gian di chuyển=0.42h
#  Quận 0: 0.42 (di chuyển) + 0.50 (nạp lại) + 3.71 (phục vụ) = 4.63h
#  Quận 1: Tổng quãng đường=22.94km, Thời gian di chuyển=0.46h
#  Quận 1: 0.46 (di chuyển) + 0.50 (nạp lại) + 3.64 (phục vụ) = 4.60h
#
# Kết quả VNS:
#  → Điểm cuối: 0.0834
#  → Cải thiện: 9.4%
#
# Trực quan hóa VNS...
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13540\4021880790.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('nipy_spectral', NUM_DISTRICTS)

# %%
print_strategic_plan(vns_solution_2, areas, vns_assignments_2, "VNS")
# Out:
# ================================================================================
#  KẾ HOẠCH CHIẾN THUẬT - Thuật toán: VNS
# ================================================================================
#  Quận 0: Tổng quãng đường=21.91km, Thời gian di chuyển=0.44h
#  Quận 0: 0.44 (di chuyển) + 0.75 (nạp lại) + 3.66 (phục vụ) = 4.85h
#  Quận 1: Tổng quãng đường=21.79km, Thời gian di chuyển=0.44h
#  Quận 1: 0.44 (di chuyển) + 0.50 (nạp lại) + 3.69 (phục vụ) = 4.63h
#
# ================================================================================================================================================================
# BẢNG TỔNG QUAN PHÂN CÔNG
# ================================================================================================================================================================
# Quận   Tài xế           Loại                 Xe               Khu vực    Tổng TG/Time     Bưu kiện/h     Trọng lượng        Chuyến   Tỷ lệ sử dụng
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# 0      2                Full-time            Xe máy to        24         4.85/8.0h        70.3 pcs/h     61.6/20 kg         4x       60.6%
# 1      1                Full-time            Xe máy to        26         4.63/8.0h        78.7 pcs/h     56.5/20 kg         3x       57.8%
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# TỔNG CỘNG                                          Workload: 7.35h  |  Bưu kiện/h: 74.4  |  Trọng lượng: 118.1kg  |  Tổng TG: 9.47h
# ================================================================================================================================================================

# %% [markdown]
# ### So sánh kết quả

# %%
# =============================================================================
# BƯỚC 5: SO SÁNH KẾT QUẢ
# =============================================================================

print("\n" + "="*80)
print(" SO SÁNH KẾT QUẢ 4 THUẬT TOÁN")
print("="*80)

results = [
    ("Lời giải ban đầu (Random)", initial_score),
    ("Local Search (1 area)", ls_score),
    ("VNS (1 area)", vns_score),
    ("Local Search Multi-Swap", ls_score_2),
    ("VNS Multi-Swap", vns_score_2),
]

print(f"\n{'Thuật toán':<35} {'Điểm số':<15} {'% Cải thiện':<15} {'Xếp hạng'}")
print("-" * 75)

sorted_results = sorted(results[1:], key=lambda x: x[1])  

for idx, (name, score) in enumerate(results):
    if idx == 0:
        print(f"{name:<35} {score:<15.4f} {'N/A':<15} {'N/A'}")
    else:
        improvement = ((initial_score - score) / initial_score * 100)
        rank = next(i+1 for i, (n, s) in enumerate(sorted_results) if n == name)
       
        print(f"{name:<35} {score:<15.4f} {improvement:>6.2f}% {" ":<8} #{rank}")

best_algorithm = sorted_results[0][0]
best_score = sorted_results[0][1]

print("\n" + "="*80)
print(f"THUẬT TOÁN TỐT NHẤT: {best_algorithm} (Score: {best_score:.4f})")
print("="*80)

print("\n📊 SO SÁNH THEO NHÓM:")
print("-" * 80)
print(f"{'Nhóm 1-area swap:':<25} LS={ls_score:.4f}, VNS={vns_score:.4f}")
print(f"{'Nhóm Multi-Swap:':<25} LS={ls_score_2:.4f}, VNS={vns_score_2:.4f}")
print("-" * 80)
# Out:
# ================================================================================
#  SO SÁNH KẾT QUẢ 4 THUẬT TOÁN
# ================================================================================
#
# Thuật toán                          Điểm số         % Cải thiện     Xếp hạng
# ---------------------------------------------------------------------------
# Lời giải ban đầu (Random)           0.0921          N/A             N/A
# Local Search (1 area)               0.0833            9.54%          #1
# VNS (1 area)                        0.0848            7.96%          #3
# Local Search Multi-Swap             0.0862            6.44%          #4
# VNS Multi-Swap                      0.0834            9.45%          #2
#
# ================================================================================
# THUẬT TOÁN TỐT NHẤT: Local Search (1 area) (Score: 0.0833)
# ================================================================================
#
# 📊 SO SÁNH THEO NHÓM:
# --------------------------------------------------------------------------------
# Nhóm 1-area swap:         LS=0.0833, VNS=0.0848
# Nhóm Multi-Swap:          LS=0.0862, VNS=0.0834
# --------------------------------------------------------------------------------
